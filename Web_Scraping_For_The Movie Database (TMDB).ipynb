# %% [markdown]
# 1)  Establish a connection to the webpage and display the page content received from the server's response.

# %%
import requests
url="https://www.themoviedb.org/movie"
needed_headers = {'User-Agent': "Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36"}
response=requests.get(url,headers = needed_headers)

# %%
response.status_code
# Out:
# 200

# %%
response.status_code == requests.codes.ok
# Out:
# True

# %% [markdown]
# The request was successful. Next step is to get the contents of the page using response.text.

# %%
page_content=response.text
page_content
# Out:
# '<!DOCTYPE html>\n<html lang="en" class="no-js">\n  <head>\n    <title>Popular Movies &#8212; The Movie Database (TMDB)</title>\n    <meta http-equiv="cleartype" content="on">\n    <meta charset="utf-8">\n    <meta name="keywords" content="Movies, TV Shows, Streaming, Reviews, API, Actors, Actresses, Photos, User Ratings, Synopsis, Trailers, Teasers, Credits, Cast">\n    <meta name="mobile-web-app-capable" content="yes">\n    <meta name="apple-mobile-web-app-capable" content="yes">\n    <meta name="viewport" content="width=device-width,initial-scale=1">\n      <meta name="description" content="The Movie Database (TMDB) is a popular, user editable database for movies and TV shows.">\n    <meta name="msapplication-TileImage" content="/assets/2/v4/icons/mstile-144x144-30e7905a8315a080978ad6aeb71c69222b72c2f75d26dab1224173a96fecc962.png">\n<meta name="msapplication-TileColor" content="#032541">\n<meta name="theme-color" content="#032541">\n<link rel="apple-touch-icon" sizes="180x180" href="/assets/2/apple-touch-icon-57ed4b3b0450fd5e9a0c20f34e814b82adaa1085c79bdde2f00ca8787b63d2c4.png">\n<link rel="icon" type="image/png" sizes="32x32" href="/assets/2/favicon-32x32-543a21832c8931d3494a68881f6afcafc58e96c5d324345377f3197a37b367b5.png">\n<link rel="icon" type="image/png" sizes="16x16" href="/assets/2/favicon-16x16-b362d267873ce9c5a39f686a11fe67fec2a72ed25fa8396c11b71aa43c938b11.png">\n<link rel="manifest" href="/manifest.json?version=3">\n    <link rel="canonical" href="https://www.themoviedb.org/movie">\n    <link rel="search" type="application/opensearchdescription+xml" title="TMDB Search" href="/opensearch.xml">\n    <link rel="preload" href="/assets/2/Consensus-3cba2c4d050ea63dbf7783173d288faf9ecb2942515a5e7f6e1beecabb2eaf72.woff2" as="font" type="font/woff2" crossorigin>\n    <link rel="preload" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-regular-f38472b9e378b8c936f55a92677f575ab69e414d7cc3706ecfefeacd994b7975.woff2" as="font" type="font/woff2" crossorigin>\n    <link rel="preload" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-italic-48273a74acbc1611b6ef1d0a771bb8ef042b9922b51d5bff560571dddcb5542a.woff2" as="font" type="font/woff2" crossorigin>\n    <link rel="preload" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-300-db9f15a13a9f8b8bc46db7756ab863e8834bd20a7a1124c4c0a5a8f7892f3e99.woff2" as="font" type="font/woff2" crossorigin>\n    <link rel="preload" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-600-6a087a74d78fc7d7b97fa1b0911c4ff3be4ff0bd5144618fd7ddc63ef1777f3a.woff2" as="font" type="font/woff2" crossorigin>\n    <link rel="preload" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-700-d67f7dff97d105f4ac5616b00fc7822ce2c33f653ece2f547995e6a71bb7b993.woff2" as="font" type="font/woff2" crossorigin>\n    <link rel="stylesheet" href="/assets/2/v4/fonts-b603098c04ec971699962bc88ab333f4df4df8f98479bf1d0e826744167c6b41.css" media="screen">\n    <link rel="stylesheet" href="/assets/2/application-4d1a86bac309736e9d1f2cf5cfbdcbc398bef8ebf96493822b861c03d8e85bd3.css" media="screen">\n    \n      <link rel="stylesheet" href="/assets/2/v4/media-ca37a789e45c1f0501ae4e046f437f5443d2e496e551111e61f3bd1e5d2701b3.css" media="screen">\n      \n      <link rel="stylesheet" href="/assets/2/v4/discover-b2c3bb76e3d2b2323e842dc4be56a342c51e08c3bb91c6a010e8b401b180f117.css" media="screen">\n      \n      <link rel="stylesheet" href="/assets/2/v4/account-767bb35541426b4fb018609f25f0fb53ac8137804b56d3e99380c6d3d07c1fc6.css" media="screen">\n      \n    <link rel="alternate" hreflang="x-default" href="https://www.themoviedb.org/movie">\n    <link rel="alternate" hreflang="af-ZA" href="https://www.themoviedb.org/movie?language=af-ZA">\n    <link rel="alternate" hreflang="ar-SA" href="h ...

# %%
type(page_content)
# Out:
# str

# %% [markdown]
# The type of the page_content obtained from server's response is "String". So in order to display the first 200 characters of the content from the server's response, I'll use string slicing.

# %%
page_content[:200]
# Out:
# '<!DOCTYPE html>\n<html lang="en" class="no-js">\n  <head>\n    <title>Popular Movies &#8212; The Movie Database (TMDB)</title>\n    <meta http-equiv="cleartype" content="on">\n    <meta charset="utf-8">\n  '

# %% [markdown]
# 2) Parse the content of HTML response using the BeautifulSoup library

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(page_content,'html.parser')

# %%
print("The title of the webpage is: ",soup.find('title').text)
# Out:
# The title of the webpage is:  Popular Movies — The Movie Database (TMDB)

# %% [markdown]
# Below is the user defined function that takes a URL string as an input and returns a correctly formulated BeautifulSoup instance as the output. It also raises exception (raise_for_status():Raises HTTPError, if one occurred.) if the status code is not 200.

# %%
def get_webpage_source(url):
    needed_headers = {'User-Agent': "Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36"}
    new_reponse=requests.get(url,headers=needed_headers)        
    try:
        new_reponse.raise_for_status()
        page_source=new_reponse.text
        output=BeautifulSoup(page_source,'html.parser')
        return output

    except requests.exceptions.RequestException as e:
        print("Error : ", e)

# %% [markdown]
# Test case 1: Working URL

# %%
popular_people_url='https://www.themoviedb.org/person'
people_content=get_webpage_source(popular_people_url)
print(people_content.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
#  <head>
#   <title>
#    Popular People — The Movie Database (TMDB)
#   </title>
#   <meta content="on" http-equiv="cleartype"/>
#   <meta charset="utf-8"/>
#   <meta content="Movies, TV Shows, Streaming, Reviews, API, Actors, Actresses, Photos, User Ratings, Synopsis, Trailers, Teasers, Credits, Cast" name="keywords"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="The Movie Database (TMDB) is a popular, user editable database for movies and TV shows." name="description"/>
#   <meta content="/assets/2/v4/icons/mstile-144x144-30e7905a8315a080978ad6aeb71c69222b72c2f75d26dab1224173a96fecc962.png" name="msapplication-TileImage"/>
#   <meta content="#032541" name="msapplication-TileColor"/>
#   <meta content="#032541" name="theme-color"/>
#   <link href="/assets/2/apple-touch-icon-57ed4b3b0450fd5e9a0c20f34e814b82adaa1085c79bdde2f00ca8787b63d2c4.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/assets/2/favicon-32x32-543a21832c8931d3494a68881f6afcafc58e96c5d324345377f3197a37b367b5.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/assets/2/favicon-16x16-b362d267873ce9c5a39f686a11fe67fec2a72ed25fa8396c11b71aa43c938b11.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/manifest.json?version=3" rel="manifest"/>
#   <link href="https://www.themoviedb.org/person" rel="canonical"/>
#   <link href="/opensearch.xml" rel="search" title="TMDB Search" type="application/opensearchdescription+xml"/>
#   <link as="font" crossorigin="" href="/assets/2/Consensus-3cba2c4d050ea63dbf7783173d288faf9ecb2942515a5e7f6e1beecabb2eaf72.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-regular-f38472b9e378b8c936f55a92677f575ab69e414d7cc3706ecfefeacd994b7975.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-italic-48273a74acbc1611b6ef1d0a771bb8ef042b9922b51d5bff560571dddcb5542a.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-300-db9f15a13a9f8b8bc46db7756ab863e8834bd20a7a1124c4c0a5a8f7892f3e99.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-600-6a087a74d78fc7d7b97fa1b0911c4ff3be4ff0bd5144618fd7ddc63ef1777f3a.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-700-d67f7dff97d105f4ac5616b00fc7822ce2c33f653ece2f547995e6a71bb7b993.woff2" rel="preload" type="font/woff2"/>
#   <link href="/assets/2/v4/fonts-b603098c04ec971699962bc88ab333f4df4df8f98479bf1d0e826744167c6b41.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/2/application-4d1a86bac309736e9d1f2cf5cfbdcbc398bef8ebf96493822b861c03d8e85bd3.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/2/v4/media-ca37a789e45c1f0501ae4e046f437f5443d2e496e551111e61f3bd1e5d2701b3.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/2/v4/account-767bb35541426b4fb018609f25f0fb53ac8137804b56d3e99380c6d3d07c1fc6.css" media="screen" rel="stylesheet"/>
#   <link href="https://www.themoviedb.org/person" hreflang="x-default" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=af-ZA" hreflang="af-ZA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ar-SA" hreflang="ar-SA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=be-BY" hreflang="be-BY" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=bg-BG" hreflang="bg-BG" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=bn-BD" hreflang="bn-BD" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ca-ES" hreflang="ca-ES" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ch-GU" hreflang="ch-GU" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=cn-CN" hreflang="cn-CN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=cs-CZ" hreflang="cs-CZ" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=cy-GB" hreflang="cy-GB" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=da-DK" hreflang="da-DK" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=de-DE" hreflang="de-DE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=el-GR" hreflang="el-GR" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-US" hreflang="en-US" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=eo-EO" hreflang="eo-EO" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=es-ES" hreflang="es-ES" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=et-EE" hreflang="et-EE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=eu-ES" hreflang="eu-ES" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=fa-IR" hreflang="fa-IR" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=fi-FI" hreflang="fi-FI" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=fr-FR" hreflang="fr-FR" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ga-IE" hreflang="ga-IE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=gd-GB" hreflang="gd-GB" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=gl-ES" hreflang="gl-ES" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=he-IL" hreflang="he-IL" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=hi-IN" hreflang="hi-IN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=hr-HR" hreflang="hr-HR" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=hu-HU" hreflang="hu-HU" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=id-ID" hreflang="id-ID" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=it-IT" hreflang="it-IT" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ja-JP" hreflang="ja-JP" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ka-GE" hreflang="ka-GE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=kk-KZ" hreflang="kk-KZ" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=kn-IN" hreflang="kn-IN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ko-KR" hreflang="ko-KR" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ky-KG" hreflang="ky-KG" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=lt-LT" hreflang="lt-LT" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=lv-LV" hreflang="lv-LV" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ml-IN" hreflang="ml-IN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=mr-IN" hreflang="mr-IN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ms-MY" hreflang="ms-MY" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=nb-NO" hreflang="nb-NO" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=nl-NL" hreflang="nl-NL" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=no-NO" hreflang="no-NO" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=pa-IN" hreflang="pa-IN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=pl-PL" hreflang="pl-PL" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=pt-PT" hreflang="pt-PT" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ro-RO" hreflang="ro-RO" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ru-RU" hreflang="ru-RU" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=si-LK" hreflang="si-LK" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=sk-SK" hreflang="sk-SK" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=sl-SI" hreflang="sl-SI" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=sq-AL" hreflang="sq-AL" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=sr-RS" hreflang="sr-RS" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=sv-SE" hreflang="sv-SE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=sw-TZ" hreflang="sw-TZ" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ta-IN" hreflang="ta-IN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=te-IN" hreflang="te-IN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=tl-PH" hreflang="tl-PH" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=th-TH" hreflang="th-TH" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=tr-TR" hreflang="tr-TR" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=uk-UA" hreflang="uk-UA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ur-PK" hreflang="ur-PK" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=vi-VN" hreflang="vi-VN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=zh-CN" hreflang="zh-CN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=zu-ZA" hreflang="zu-ZA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ar-AE" hreflang="ar-AE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ar-BH" hreflang="ar-BH" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ar-EG" hreflang="ar-EG" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ar-IQ" hreflang="ar-IQ" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ar-JO" hreflang="ar-JO" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ar-LY" hreflang="ar-LY" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ar-MA" hreflang="ar-MA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ar-QA" hreflang="ar-QA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ar-YE" hreflang="ar-YE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ar-TD" hreflang="ar-TD" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ca-AD" hreflang="ca-AD" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=de-AT" hreflang="de-AT" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=de-CH" hreflang="de-CH" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=el-CY" hreflang="el-CY" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-AG" hreflang="en-AG" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-AU" hreflang="en-AU" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-BB" hreflang="en-BB" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-BZ" hreflang="en-BZ" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-CA" hreflang="en-CA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-CM" hreflang="en-CM" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-GB" hreflang="en-GB" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-GG" hreflang="en-GG" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-GH" hreflang="en-GH" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-GI" hreflang="en-GI" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-GY" hreflang="en-GY" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-IE" hreflang="en-IE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-JM" hreflang="en-JM" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-KE" hreflang="en-KE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-LC" hreflang="en-LC" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-MW" hreflang="en-MW" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-NZ" hreflang="en-NZ" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-PG" hreflang="en-PG" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-TC" hreflang="en-TC" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-ZM" hreflang="en-ZM" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=en-ZW" hreflang="en-ZW" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=es-AR" hreflang="es-AR" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=es-CL" hreflang="es-CL" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=es-DO" hreflang="es-DO" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=es-EC" hreflang="es-EC" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=es-GT" hreflang="es-GT" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=es-GQ" hreflang="es-GQ" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=es-HN" hreflang="es-HN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=es-MX" hreflang="es-MX" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=es-NI" hreflang="es-NI" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=es-PA" hreflang="es-PA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=es-PE" hreflang="es-PE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=es-PY" hreflang="es-PY" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=es-SV" hreflang="es-SV" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=es-UY" hreflang="es-UY" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=fr-BF" hreflang="fr-BF" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=fr-CA" hreflang="fr-CA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=fr-CD" hreflang="fr-CD" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=fr-CI" hreflang="fr-CI" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=fr-GF" hreflang="fr-GF" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=fr-GP" hreflang="fr-GP" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=fr-MC" hreflang="fr-MC" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=fr-ML" hreflang="fr-ML" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=fr-MU" hreflang="fr-MU" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=fr-PF" hreflang="fr-PF" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=it-VA" hreflang="it-VA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ms-SG" hreflang="ms-SG" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=nl-BE" hreflang="nl-BE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=pt-AO" hreflang="pt-AO" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=pt-BR" hreflang="pt-BR" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=pt-MZ" hreflang="pt-MZ" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=ro-MD" hreflang="ro-MD" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=sr-ME" hreflang="sr-ME" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=sq-XK" hreflang="sq-XK" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=zh-HK" hreflang="zh-HK" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=zh-SG" hreflang="zh-SG" rel="alternate"/>
#   <link href="https://www.themoviedb.org/person?language=zh-TW" hreflang="zh-TW" rel="alternate"/>
#   <script charset="UTF-8" data-domain-script="23223fbb-5c84-48df-836d-0a83fb7b2c03" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript">
#   </script>
#   <script>
#    function OptanonWrapper() {}
#   </script>
#   <script src="/assets/2/lozad.min-7f803337d01a657607bca6b20e06f371c3895b36a5f2be03a8fa9b5e16c9a83e.js">
#   </script>
#   <script src="/assets/2/jquery-3.6.0.min-ff1523fb7389539c84c65aba19260648793bb4f5e29329d2ee8804bc37a3fe6e.js">
#   </script>
#   <script>
#    $(function() {
#         jQuery.event.special.touchstart = {
#           setup: function(_, ns, handle) {
#             this.addEventListener("touchstart", handle, { passive: !ns.includes("noPreventDefault") });
#           }
#         };
#         jQuery.event.special.touchmove = {
#           setup: function(_, ns, handle) {
#             this.addEventListener("touchmove", handle, { passive: !ns.includes("noPreventDefault") });
#           }
#         };
#       });
#       detected_timezone = Intl.DateTimeFormat().resolvedOptions().timeZone;
#         timezone = detected_timezone;
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-5QWVXV');
#   </script>
#   <script src="/assets/2/kendo-93daa31ab3dcca8723478255a3b3c3f0a9e6672dddc612e114391786423c1870.js">
#   </script>
#   <script src="/assets/2/kendo-2021.1.204/cultures/kendo.culture.en-US.min-61ce5636474a35333ecff74fe30c528d459bcee29b3b32fc0c58ac77de788b34.js">
#   </script>
#   <script>
#    kendo.culture("en-US");
#   </script>
#   <script src="/assets/2/kendo-2021.1.204/messages/kendo.messages.en-US.min-79da68ae0221b4fd7978805d0c79cc7f682fddace5f2137aa0dae8fe1c5ddacd.js">
#   </script>
#   <script src="/assets/2/application-a005f527fa2f63db2e7eb7124265a53965cb0ab5268caebc32c41305b4da51b1.js">
#   </script>
#   <script src="/assets/2/pusher.min-ee61b1e19799dd5aae92a3d91bc970e6147c6fe4395eacf3e499ed1451650f22.js">
#   </script>
#   <script defer="" src="/assets/2/application.desktop-ea69249141a43ef7c6a59a19ee40eface5e171cf03eefffddb488574a66dea02.js">
#   </script>
#  </head>
#  <body class="en v4">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5QWVXV" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div class="page_wrap person_wrap">
#    <header class="normal smaller no_animation smaller subtle">
#     <div class="content">
#      <div class="sub_media">
#       <div class="nav_wrapper">
#        <a class="logo" href="/">
#         <img alt="The Movie Database (TMDB)" height="20" src="/assets/2/v4/logos/v2/blue_short-8e7b30f73a4020692ccca9c88bafe5dcb6f8a62a4c6bc55cd9ba82bb2cd95f6c.svg" width="154"/>
#        </a>
#        <ul class="dropdown_menu navigation">
#         <li>
#          <a class="no_click" href="/movie">
#           Movies
#          </a>
#          <ul>
#           <li>
#            <a href="/movie">
#             Popular
#            </a>
#           </li>
#           <li>
#            <a href="/movie/now-playing">
#             Now Playing
#            </a>
#           </li>
#           <li>
#            <a href="/movie/upcoming">
#             Upcoming
#            </a>
#           </li>
#           <li>
#            <a href="/movie/top-rated">
#             Top Rated
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="no_click" href="/tv">
#           TV Shows
#          </a>
#          <ul>
#           <li>
#            <a href="/tv">
#             Popular
#            </a>
#           </li>
#           <li>
#            <a href="/tv/airing-today">
#             Airing Today
#            </a>
#           </li>
#           <li>
#            <a href="/tv/on-the-air">
#             On TV
#            </a>
#           </li>
#           <li>
#            <a href="/tv/top-rated">
#             Top Rated
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="no_click" href="/person">
#           People
#          </a>
#          <ul>
#           <li>
#            <a href="/person">
#             Popular People
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="no_click" href="#">
#           More
#          </a>
#          <ul>
#           <li>
#            <a href="/discuss">
#             Discussions
#            </a>
#           </li>
#           <li>
#            <a href="/leaderboard">
#             Leaderboard
#            </a>
#           </li>
#           <li>
#            <a href="/talk">
#             Support
#            </a>
#           </li>
#           <li>
#            <a href="https://developer.themoviedb.org/docs" target="_blank">
#             API
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </div>
#       <div class="flex">
#        <ul class="primary">
#         <li class="glyph new_buttons">
#          <a class="new_icon no_click" href="#">
#           <span class="glyphicons_v2 plus white">
#           </span>
#          </a>
#         </li>
#         <li class="translate">
#          <div>
#           en
#          </div>
#         </li>
#         <li>
#          <a href="/login">
#           Login
#          </a>
#         </li>
#         <li>
#          <a href="/signup">
#           Join TMDB
#          </a>
#         </li>
#         <li class="glyph search_buttons">
#          <a class="search" href="/search">
#           <span class="glyphicons_v2 search blue">
#           </span>
#          </a>
#          <a class="close hide" href="/search">
#           <span class="glyphicons_v2 menu-close invert svg">
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="search_bar hide">
#      <section class="search show_search_false">
#       <div class="sub_media">
#        <form accept-charset="utf-8" action="/search" id="search_form" method="get">
#         <label>
#          <input autocomplete="off" autocorrect="off" autofill="off" dir="auto" id="search_v4" name="query" placeholder="Search for a movie, tv show, person..." spellcheck="false" tabindex="1" type="text" value=""/>
#         </label>
#         <input disabled="" type="submit"/>
#        </form>
#       </div>
#      </section>
#     </div>
#    </header>
#    <main class="smaller subtle show_search_false" id="main">
#     <div class="inner_block">
#      <div class="inner_content">
#       <div class="content">
#        <h2>
#         <span class="title">
#          Popular People
#         </span>
#        </h2>
#        <div class="results flex results_profile_card">
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder two">
#            <a alt="Jeremy Piven" class="result" href="/person/12799" id="person_12799" title="Jeremy Piven">
#             <img alt="Jeremy Piven" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/pqdR8zqAWF87chGYlbdYr0YfC7g.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/pqdR8zqAWF87chGYlbdYr0YfC7g.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/pqdR8zqAWF87chGYlbdYr0YfC7g.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/12799">
#              Jeremy Piven
#             </a>
#            </p>
#            <p class="sub">
#             Cars, Serendipity, and So Undercover
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder one">
#            <a alt="Sydney Sweeney" class="result" href="/person/115440" id="person_115440" title="Sydney Sweeney">
#             <img alt="Sydney Sweeney" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/wrPmsC9YATcnyAxvXEdGshccbqU.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/wrPmsC9YATcnyAxvXEdGshccbqU.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/wrPmsC9YATcnyAxvXEdGshccbqU.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/115440">
#              Sydney Sweeney
#             </a>
#            </p>
#            <p class="sub">
#             Euphoria, The Voyeurs, and Once Upon a Time… in Hollywood
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder two">
#            <a alt="Jason Statham" class="result" href="/person/976" id="person_976" title="Jason Statham">
#             <img alt="Jason Statham" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/lldeQ91GwIVff43JBrpdbAAeYWj.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/lldeQ91GwIVff43JBrpdbAAeYWj.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/lldeQ91GwIVff43JBrpdbAAeYWj.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/976">
#              Jason Statham
#             </a>
#            </p>
#            <p class="sub">
#             Snatch, The Meg, and The Transporter
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder two">
#            <a alt="Glen Powell" class="result" href="/person/83271" id="person_83271" title="Glen Powell">
#             <img alt="Glen Powell" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/lRbbndkwOXyvep9Y7kHiwbh9Ji5.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/lRbbndkwOXyvep9Y7kHiwbh9Ji5.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/lRbbndkwOXyvep9Y7kHiwbh9Ji5.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/83271">
#              Glen Powell
#             </a>
#            </p>
#            <p class="sub">
#             Top Gun: Maverick, Set It Up, and Hidden Figures
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder one">
#            <a alt="Jenna Ortega" class="result" href="/person/974169" id="person_974169" title="Jenna Ortega">
#             <img alt="Jenna Ortega" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/aw0q3h9GDoUF69oLXg1m7Dk5Adz.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/aw0q3h9GDoUF69oLXg1m7Dk5Adz.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/aw0q3h9GDoUF69oLXg1m7Dk5Adz.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/974169">
#              Jenna Ortega
#             </a>
#            </p>
#            <p class="sub">
#             Wednesday, Scream, and X
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder two">
#            <a alt="Jarred Harper" class="result" href="/person/3450482" id="person_3450482" title="Jarred Harper">
#             <img alt="Jarred Harper" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/iRImFVWY56bOlkeKXtUFo1sgUNh.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/iRImFVWY56bOlkeKXtUFo1sgUNh.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/iRImFVWY56bOlkeKXtUFo1sgUNh.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/3450482">
#              Jarred Harper
#             </a>
#            </p>
#            <p class="sub">
#             The Institute, American Housewife, and In Pursuit with John Walsh
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder one">
#            <a alt="Kelly Reilly" class="result" href="/person/17521" id="person_17521" title="Kelly Reilly">
#             <img alt="Kelly Reilly" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/gof8bWW9E7MH30GpvA97PwGiIuu.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/gof8bWW9E7MH30GpvA97PwGiIuu.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/gof8bWW9E7MH30GpvA97PwGiIuu.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/17521">
#              Kelly Reilly
#             </a>
#            </p>
#            <p class="sub">
#             Flight, Sherlock Holmes, and Eden Lake
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder two">
#            <a alt="Tom Hanks" class="result" href="/person/31" id="person_31" title="Tom Hanks">
#             <img alt="Tom Hanks" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/xndWFsBlClOJFRdhSt4NBwiPq2o.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/xndWFsBlClOJFRdhSt4NBwiPq2o.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/xndWFsBlClOJFRdhSt4NBwiPq2o.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/31">
#              Tom Hanks
#             </a>
#            </p>
#            <p class="sub">
#             Forrest Gump, Toy Story, and The Green Mile
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder two">
#            <a alt="Olivier Renaud" class="result" href="/person/1799766" id="person_1799766" title="Olivier Renaud">
#             <img alt="Olivier Renaud" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/r1PKI00FM4kovA2AQfnWhC1BU13.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/r1PKI00FM4kovA2AQfnWhC1BU13.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/r1PKI00FM4kovA2AQfnWhC1BU13.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/1799766">
#              Olivier Renaud
#             </a>
#            </p>
#            <p class="sub">
#             Midnight at the Magnolia, Planes, Trains, and Christmas Trees, and Loving Christmas
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder two">
#            <a alt="Timothée Chalamet" class="result" href="/person/1190668" id="person_1190668" title="Timothée Chalamet">
#             <img alt="Timothée Chalamet" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/BE2sdjpgsa2rNTFa66f7upkaOP.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/BE2sdjpgsa2rNTFa66f7upkaOP.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/BE2sdjpgsa2rNTFa66f7upkaOP.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/1190668">
#              Timothée Chalamet
#             </a>
#            </p>
#            <p class="sub">
#             Call Me by Your Name, Dune, and The King
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder two">
#            <a alt="Alan Ritchson" class="result" href="/person/64295" id="person_64295" title="Alan Ritchson">
#             <img alt="Alan Ritchson" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/wdmLUSPEC7dXuqnjTM4NgbjvTKk.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/wdmLUSPEC7dXuqnjTM4NgbjvTKk.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/wdmLUSPEC7dXuqnjTM4NgbjvTKk.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/64295">
#              Alan Ritchson
#             </a>
#            </p>
#            <p class="sub">
#             Reacher, Teenage Mutant Ninja Turtles, and The Hunger Games: Catching Fire
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder two">
#            <a alt="Russell Crowe" class="result" href="/person/934" id="person_934" title="Russell Crowe">
#             <img alt="Russell Crowe" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/fbzD4utSGJlsV8XbYMLoMdEZ1Fc.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/fbzD4utSGJlsV8XbYMLoMdEZ1Fc.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/fbzD4utSGJlsV8XbYMLoMdEZ1Fc.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/934">
#              Russell Crowe
#             </a>
#            </p>
#            <p class="sub">
#             Gladiator, A Beautiful Mind, and Noah
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder one">
#            <a alt="Tzu Hsuan Chan" class="result" href="/person/3682439" id="person_3682439" title="Tzu Hsuan Chan">
#             <img alt="Tzu Hsuan Chan" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/x4gmtjefQfZn05SAyOc2UcmlklE.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/x4gmtjefQfZn05SAyOc2UcmlklE.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/x4gmtjefQfZn05SAyOc2UcmlklE.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/3682439">
#              Tzu Hsuan Chan
#             </a>
#            </p>
#            <p class="sub">
#             The Post-Truth World, The Bridge Curse: Ritual, and A Balloon's Journey
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder one">
#            <a alt="Emma Stone" class="result" href="/person/54693" id="person_54693" title="Emma Stone">
#             <img alt="Emma Stone" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/3UaYw9KF4fEXRMRWhf25aGJpAW2.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/3UaYw9KF4fEXRMRWhf25aGJpAW2.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/3UaYw9KF4fEXRMRWhf25aGJpAW2.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/54693">
#              Emma Stone
#             </a>
#            </p>
#            <p class="sub">
#             Cruella, The Amazing Spider-Man, and La La Land
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder one">
#            <a alt="Piper Perabo" class="result" href="/person/15555" id="person_15555" title="Piper Perabo">
#             <img alt="Piper Perabo" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/aP9QqLm4JZxLwp2CiUbEh5zrpVI.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/aP9QqLm4JZxLwp2CiUbEh5zrpVI.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/aP9QqLm4JZxLwp2CiUbEh5zrpVI.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/15555">
#              Piper Perabo
#             </a>
#            </p>
#            <p class="sub">
#             Coyote Ugly, The Prestige, and Looper
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder two">
#            <a alt="Tommy Lee Jones" class="result" href="/person/2176" id="person_2176" title="Tommy Lee Jones">
#             <img alt="Tommy Lee Jones" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/mCiZNRAzbnPojJEZwVZWLw9kzxR.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/mCiZNRAzbnPojJEZwVZWLw9kzxR.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/mCiZNRAzbnPojJEZwVZWLw9kzxR.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/2176">
#              Tommy Lee Jones
#             </a>
#            </p>
#            <p class="sub">
#             Men in Black, Captain America: The First Avenger, and Men in Black 3
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder two">
#            <a alt="Jacob Elordi" class="result" href="/person/2034418" id="person_2034418" title="Jacob Elordi">
#             <img alt="Jacob Elordi" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/khfLyxY9gsKiLFoz2zj0h3uhDFJ.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/khfLyxY9gsKiLFoz2zj0h3uhDFJ.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/khfLyxY9gsKiLFoz2zj0h3uhDFJ.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/2034418">
#              Jacob Elordi
#             </a>
#            </p>
#            <p class="sub">
#             The Kissing Booth 2, The Kissing Booth, and Euphoria
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder two">
#            <a alt="Cole Hauser" class="result" href="/person/6614" id="person_6614" title="Cole Hauser">
#             <img alt="Cole Hauser" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/kJyUtNZREd7mes21OrWiCtOugPL.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/kJyUtNZREd7mes21OrWiCtOugPL.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/kJyUtNZREd7mes21OrWiCtOugPL.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/6614">
#              Cole Hauser
#             </a>
#            </p>
#            <p class="sub">
#             2 Fast 2 Furious, Good Will Hunting, and Pitch Black
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder one">
#            <a alt="Samyuktha Viola Viswanathan" class="result" href="/person/3279864" id="person_3279864" title="Samyuktha Viola Viswanathan">
#             <img alt="Samyuktha Viola Viswanathan" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/poEXJ3oa8w41GDPahOX39gJR92U.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/poEXJ3oa8w41GDPahOX39gJR92U.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/poEXJ3oa8w41GDPahOX39gJR92U.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/3279864">
#              Samyuktha Viola Viswanathan
#             </a>
#            </p>
#            <p class="sub">
#             Engga Hostel, Sweet Kaaram Coffee, and Oh Manapenne!
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="fifty_square">
#          <div class="item profile card">
#           <div class="image_content glyphicons_v2 picture grey profile no_image_holder two">
#            <a alt="Barry Keoghan" class="result" href="/person/1290466" id="person_1290466" title="Barry Keoghan">
#             <img alt="Barry Keoghan" class="profile" loading="lazy" src="https://media.themoviedb.org/t/p/w235_and_h235_face/ngoitknM6hw8fffLywyvjzy6Iti.jpg" srcset="https://media.themoviedb.org/t/p/w235_and_h235_face/ngoitknM6hw8fffLywyvjzy6Iti.jpg 1x, https://media.themoviedb.org/t/p/w470_and_h470_face/ngoitknM6hw8fffLywyvjzy6Iti.jpg 2x"/>
#            </a>
#           </div>
#           <div class="meta">
#            <p class="name">
#             <a href="/person/1290466">
#              Barry Keoghan
#             </a>
#            </p>
#            <p class="sub">
#             Dunkirk, Saltburn, and Eternals
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="pagination_wrapper">
#          <nav class="pagy-nav pagination">
#           <span class="page prev disabled">
#            ‹ Prev
#           </span>
#           <span class="page active">
#            1
#           </span>
#           <span class="page">
#            <a href="/person?page=2" rel="next">
#             2
#            </a>
#           </span>
#           <span class="page">
#            <a href="/person?page=3">
#             3
#            </a>
#           </span>
#           <span class="page">
#            <a href="/person?page=4">
#             4
#            </a>
#           </span>
#           <span class="page">
#            <a href="/person?page=5">
#             5
#            </a>
#           </span>
#           <span class="page gap">
#            …
#           </span>
#           <span class="page">
#            <a href="/person?page=162647">
#             162647
#            </a>
#           </span>
#           <span class="page next">
#            <a aria-label="next" href="/person?page=2" rel="next">
#             Next ›
#            </a>
#           </span>
#          </nav>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </main>
#   </div>
#   <!-- page_wrap opened in html_head -->
#   <footer class="single_column person">
#    <nav>
#     <div class="join">
#      <img alt="The Movie Database (TMDB)" height="94" src="/assets/2/v4/logos/v2/blue_square_2-d537fb228cf3ded904ef09b136fe3fec72548ebc1fea3fbbd1ad9e36364db38b.svg" width="130"/>
#      <a class="rounded" href="/signup">
#       Join the Community
#      </a>
#     </div>
#     <div>
#      <h3>
#       The Basics
#      </h3>
#      <ul>
#       <li>
#        <a href="/about">
#         About TMDB
#        </a>
#       </li>
#       <li>
#        <a href="/about/staying-in-touch">
#         Contact Us
#        </a>
#       </li>
#       <li>
#        <a href="/talk">
#         Support Forums
#        </a>
#       </li>
#       <li>
#        <a href="https://developer.themoviedb.org/docs" target="_blank">
#         API
#        </a>
#       </li>
#       <li>
#        <a href="https://status.themoviedb.org/" rel="noopener" target="_blank">
#         System Status
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div>
#      <h3>
#       Get Involved
#      </h3>
#      <ul>
#       <li>
#        <a href="/bible">
#         <span class="glyphicons glyphicons-asterisk">
#         </span>
#         Contribution Bible
#        </a>
#       </li>
#       <li>
#        <a href="/movie/new">
#         Add New Movie
#        </a>
#       </li>
#       <li>
#        <a href="/tv/new">
#         Add New TV Show
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div>
#      <h3>
#       Community
#      </h3>
#      <ul>
#       <li>
#        <a href="/documentation/community/guidelines">
#         Guidelines
#        </a>
#       </li>
#       <li>
#        <a href="/discuss">
#         Discussions
#        </a>
#       </li>
#       <li>
#        <a href="/leaderboard">
#         Leaderboard
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div>
#      <h3>
#       Legal
#      </h3>
#      <ul>
#       <li>
#        <a href="/terms-of-use">
#         Terms of Use
#        </a>
#       </li>
#       <li>
#        <a href="/api-terms-of-use">
#         API Terms of Use
#        </a>
#       </li>
#       <li>
#        <a href="/privacy-policy">
#         Privacy Policy
#        </a>
#       </li>
#       <li>
#        <a href="/dmca-policy">
#         DMCA Policy
#        </a>
#       </li>
#      </ul>
#     </div>
#    </nav>
#    <section>
#     Build 68a6454 (6590)
#    </section>
#   </footer>
#   <div class="hide" id="new_media_template">
#    <div class="settings_content">
#     <p>
#      Can't find a movie or TV show? Login to create it.
#     </p>
#    </div>
#   </div>
#   <div class="hide" id="settings_tooltip">
#    <div class="settings_content">
#     <div class="group no_pad">
#      <p>
#       <a href="/login">
#        Login
#       </a>
#      </p>
#     </div>
#     <div class="group">
#      <p>
#       <a href="/signup">
#        Sign Up
#       </a>
#      </p>
#     </div>
#    </div>
#   </div>
#   <div class="hide" id="keyboard_shortcuts_popup">
#    <div class="content k-flex-col">
#     <div class="keyboard_shortcuts">
#      <div class="column">
#       <h3>
#        Global
#       </h3>
#       <div>
#        <span>
#         s
#        </span>
#        focus the search bar
#       </div>
#       <div>
#        <span>
#         p
#        </span>
#        open profile menu
#       </div>
#       <div>
#        <span>
#         esc
#        </span>
#        close an open window
#       </div>
#       <div>
#        <span>
#         ?
#        </span>
#        open keyboard shortcut window
#       </div>
#       <h3>
#        On media pages
#       </h3>
#       <div>
#        <span>
#         b
#        </span>
#        go back (or to parent when applicable)
#       </div>
#       <div>
#        <span>
#         e
#        </span>
#        go to edit page
#       </div>
#       <h3>
#        On TV season pages
#       </h3>
#       <div>
#        <span>
#         →
#        </span>
#        (right arrow) go to next season
#       </div>
# ...
#           dataTextField: "title",
#           template: kendo.template($("#slim_multi_search_template").html()),
#           noDataTemplate: $("#search_no_data_template").html(),
#           dataSource: {
#             type: "json",
#             serverFiltering: true,
#             transport: {
#               read: '/search/trending',
#               parameterMap: function() {
#                 return { query: $("#search_v4").data("kendoAutoComplete").value() };
#               }
#             },
#             schema: {
#               data: "results"
#             }
#           },
#           popup: {
#             appendTo: $("header")
#           },
#           filtering: function(e) {
#             var filter = e.filter != undefined ? e.filter.value : "";
#             if (filter == '') {
#               if ( ($('#search_v4-list #trending_search_header_template').length) == 0 ) {
#                 // $('#search_v4_listbox').empty();
#                 $('#search_v4-list').prepend($("#search_v4_headerTemplate").html());
#               }
#             } else {
#               $("#trending_search_header_template").remove();
#             }
#           },
#           select: function(e) {
#             processing_selected_item = true;
#             processSelectedItem(e);
#           },
#           close: function(e) {
#             // e.preventDefault();
#           }
#         }).data("kendoAutoComplete");
#
#         $('#search_v4').keydown(function(event) {
#           if (event.keyCode == 13) {
#             if (processing_selected_item) {
#               return;
#             } else {
#               processSelectedItem(null);
#             }
#           }
#         });
#
#         $('header #search_form').submit(function() {
#           return false;
#         });
#
#         var autocompleteInput = $('section.search .k-autocomplete input');
#         autocompleteInput.on('focus', function (e) {
#           var value = autocompleteInput.val();
#           if (value == null || value == '') {
#             $("#search_v4").data("kendoAutoComplete").search('');
#           } else {
#             var fieldLength = value.length;
#             autocompleteInput[0].setSelectionRange(fieldLength, fieldLength);
#           }
#         });
#
#         $('li.search_buttons a.search').on('click', function(e) {
#           e.preventDefault();
#           showSearch(true);
#         });
#
#         $('li.search_buttons a.close').on('click', function(e) {
#           e.preventDefault();
#           showSearch(false);
#         });
#
#         $('main.show_search_false').on('click', function(e) {
#           showSearch(false);
#         });
#
#         $('header span.k-i-close[title="clear"]').on('click', function(e) {
#           $('#search_v4').data("kendoAutoComplete").focus();
#         });
#
#
#         public_media_type_map = { 'movie': 'Movie', 'tv': 'TV Show', 'person': 'Person' };
#
#
#         $(document).on('keydown', null, 'b', function() {
#           if ( $('a.keyboard_s.parent').length ) {
#             $('a.keyboard_s.parent')[0].click();
#           }
#         });
#
#         $(document).on('keyup', null, 's', function() {
#           if ( $('#search_v4').length ) {
#             showSearch(true);
#           }
#         });
#
#         $(document).on('keyup', null, 'shift+/', function() {
#           keyboard_shortcut_popup.open();
#         });
#
#         $(document).on('keydown', null, 'left', function() {
#           if ( $('span.previous a.keyboard_s').length ) {
#             $('span.previous a.keyboard_s')[0].click();
#           }
#         });
#
#         $(document).on('keydown', null, 'right', function() {
#           if ( $('span.next a.keyboard_s').length ) {
#             $('span.next a.keyboard_s')[0].click();
#           }
#         });
#
#         $(document).on('keydown', null, 'm', function() {
#           if ( $('#new_shortcut_bar').length ) {
#             $("#new_shortcut_bar").focus();
#           }
#         });
#
#         $(document).on('keydown', null, 'esc', function() {
#           if ( $('div.custom_bg.keyboard_s').length && $('#ott_offers_window a.close').length ) {
#             $('#ott_offers_window a.close')[0].click();
#           }
#         });
#       });
#
#       var gender_lookup = {
#         0: 'two',
#         1: 'one',
#         2: 'two',
#         3: 'two'
#       }
#   </script>
#   <script id="person_template" type="text/x-kendo-tmpl">
#    <div class="item profile list_item grid_item">
#         <div class="image_content profile">
#           <a class="result" href="/person/${data.url}" title="${data.name}" alt="${data.name}">
#             # if (data.profile_path) { #
#               <img class="" src="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path}" alt="${data.name}" width="45" height="45" srcset="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path} 1x, https://media.themoviedb.org/t/p/w132_and_h132_face${data.profile_path} 2x">
#             # } else { #
#               <div class="glyphicons_v2 picture profile ${gender_lookup[data.gender]} grey no_image_holder w45_and_h45"></div>
#             # } #
#           </a>
#         </div>
#
#         <div class="content">
#           <p class="name"><a class="result" href="/person/${data.url}" title="${data.name}" alt="${data.name}">${data.name}</a></p>
#
#           # if (data.known_for) { #
#             <p class="sub">${data.known_for}</p>
#           # } #
#         </div>
#       </div>
#   </script>
#   <script id="person_template_with_known_for" type="text/x-kendo-tmpl">
#    <div class="item profile list_item known_for">
#         <div class="image_content profile">
#           # if (data.profile_path) { #
#             <img class="" src="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path}" alt="${data.name}" width="45" height="45" srcset="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path} 1x, https://media.themoviedb.org/t/p/w132_and_h132_face${data.profile_path} 2x">
#           # } else { #
#             <div class="glyphicons_v2 picture grey no_image_holder w45_and_h45 profile"></div>
#           # } #
#         </div>
#
#         <div class="content">
#           <p class="name">${data.name}</p>
#           # if (data.known_for) { #
#             <p class="sub">${data.known_for_department} &bull; ${data.known_for}</p>
#           # } else { #
#             <p class="sub">No known credits.</p>
#           # } #
#         </div>
#       </div>
#   </script>
#   <script id="person_result_template" type="text/x-kendo-tmpl">
#    <div class="ac_item profile list_item known_for">
#         <div class="image_content profile">
#           # if (data.profile_path) { #
#             <img class="" src="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path}" alt="${data.name}" width="45" height="45" srcset="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path} 1x, https://media.themoviedb.org/t/p/w132_and_h132_bestv2${data.profile_path} 2x">
#           # } else { #
#             <div class="glyphicons_v2 picture grey no_image_holder w45_and_h45 profile"></div>
#           # } #
#         </div>
#
#         <div class="content">
#           <p class="name">${data.name}</p>
#           # if (data.known_for) { #
#             <p class="sub">
#               # if (data.media_type) { #
#                 <span class="media_type person">#= public_media_type_map[data.media_type] # &bull; </span>
#               # } #
#               # for (var i = 0; i < data.known_for.length; i++) { #
#               <span class="comma">#= data.known_for[i].title ? data.known_for[i].title : data.known_for[i].name #</span>
#               # } #
#             </p>
#           # } else { #
#             <p class="sub">No known credits.</p>
#           # } #
#         </div>
#       </div>
#   </script>
#   <script id="movie_result_template" type="text/x-kendo-tmpl">
#    <div class="ac_results">
#         <div class="ac_item poster list_item">
#           <div class="image_content poster">
#             # if (data.poster_path) { #
#               <img class="" src="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path}" alt="${data.title}" width="45" height="67" srcset="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path} 1x, https://media.themoviedb.org/t/p/w90_and_h134_bestv2${data.poster_path} 2x">
#             # } else { #
#               <div class="glyphicons_v2 picture grey no_image_holder w45_and_h67"></div>
#             # } #
#           </div>
#
#           <div class="content">
#             <p class="name">${data.title}</p>
#             <p class="sub">
#               # if (data.media_type) { #
#                 <span class="media_type movie">#= public_media_type_map[data.media_type] # &bull; </span>
#               # } #
#               # if (data.original_title !== data.title) { #
#                 <span class="comma"><span class="original_title">#= data.original_title #</span></span>
#               # } #
#               # if (data.release_date) { #
#                 <span class="comma"><span class="release_date">#= data.release_date #</span></span>
#               # } #
#             </p>
#           </div>
#         </div>
#       </div>
#   </script>
#   <script id="tv_show_result_template" type="text/x-kendo-tmpl">
#    <div class="ac_item poster list_item">
#         <div class="image_content poster">
#           # if (data.poster_path) { #
#             <img class="" src="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path}" alt="${data.title}" width="45" height="67" srcset="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path} 1x, https://media.themoviedb.org/t/p/w90_and_h134_bestv2${data.poster_path} 2x">
#           # } else { #
#             <div class="glyphicons_v2 picture grey no_image_holder w45_and_h67"></div>
#           # } #
#         </div>
#
#         <div class="content">
#           <p class="name">${data.name}</p>
#           <p class="sub">
#             # if (data.media_type) { #
#                 <span class="media_type tv">#= public_media_type_map[data.media_type] # &bull; </span>
#               # } #
#             # if (data.original_name !== data.name) { #
#               <span class="comma"><span class="original_title">#= data.original_name #</span></span>
#             # } #
#             # if (data.first_air_date) { #
#               <span class="comma"><span class="release_date">#= data.first_air_date #</span></span>
#             # } #
#           </p>
#         </div>
#       </div>
#   </script>
#   <script id="slim_movie_result_template" type="text/x-kendo-tmpl">
#    <div class="ac_item poster list_item">
#         <div class="image_content poster">
#           # if (data.poster_path) { #
#             <img class="" src="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path}" alt="${data.title}" width="45" height="67" srcset="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path} 1x, https://media.themoviedb.org/t/p/w90_and_h134_bestv2${data.poster_path} 2x">
#           # } else { #
#             <div class="glyphicons_v2 picture grey no_image_holder w45_and_h67"></div>
#           # } #
#         </div>
#
#         <div class="content">
#           <p class="name">${data.title}</p>
#           <p class="sub">
#             # if (data.original_title !== data.title) { #
#               <span class="comma"><span class="original_title">#= data.original_title #</span></span>
#             # } #
#             # if (data.release_date) { #
#               <span class="comma"><span class="release_date">#= data.release_date #</span></span>
#             # } #
#           </p>
#         </div>
#
#         <p><span class="media_type movie">#= public_media_type_map[data.media_type] #</span></p>
#       </div>
#   </script>
#   <script id="multi_search_template" type="text/x-kendo-tmpl">
#    <div class="ac_results">
#         # if (data.media_type == 'movie') { #
#           #= kendo.render(kendo.template($("\\#movie_result_template").html()), [data]) #
#         # } else if (data.media_type == 'tv') { #
#           #= kendo.render(kendo.template($("\\#tv_show_result_template").html()), [data]) #
#         # } else if (data.media_type == 'person') { #
#           #= kendo.render(kendo.template($("\\#person_result_template").html()), [data]) #
#         # } #
#       </div>
#   </script>
#   <script id="search_v4_headerTemplate" type="text/x-kendo-template">
#    <div id="trending_search_header_template" class="slim_search_results_header">
#         <div class="wrapper">
#           <h2><span class="glyphicons_v2 trending"></span> Trending</h2>
#         </div>
#       </div>
#   </script>
#   <script id="search_no_data_template" type="text/x-kendo-template">
#    <div class="slim_search_results_header no_data">
#         <div class="wrapper">
#           <h2>No Results</h2>
#         </div>
#       </div>
#   </script>
#   <script id="slim_multi_search_template" type="text/x-kendo-tmpl">
#    # if (data.media_type == 'movie') { #
#         <div class="slim_search_results slim">
#           <div class="wrapper">
#             <div class="glyphicons_v2 film"></div>
#             <p>#= data.name # <span>in Movies</span></p>
#           </div>
#         </div>
#       # } else if (data.media_type == 'tv') { #
#         <div class="slim_search_results slim">
#           <div class="wrapper">
#             <div class="glyphicons_v2 tv"></div>
#             <p>#= data.name # <span>in TV Shows</span></p>
#           </div>
#         </div>
#       # } else if (data.media_type == 'person') { #
#         <div class="slim_search_results slim">
#           <div class="wrapper">
#             <div class="glyphicons_v2 user"></div>
#             <p>#= data.name # <span>in People</span></p>
#           </div>
#         </div>
#       # } else { #
#         <div class="slim_search_results slim">
#           <div class="wrapper">
#             <div class="glyphicons_v2 search"></div>
#             <p>#= data #</p>
#           </div>
#         </div>
#       # } #
#   </script>
#   <script id="delete-confirmation" type="text/x-kendo-template">
#    <section class="window_content">
#         <p class="delete-message">Are you sure?</p>
#
#         <button class="delete-cancel k-button">No</button>
#         <button class="delete-confirm k-button">Yes</button>
#       </section>
#   </script>
#   <div id="dialog_window">
#   </div>
#   <span class="hide" id="notification">
#   </span>
#   <script id="errorTemplate" type="text/x-kendo-template">
#    <div class="notification error">
#         <span>
#           <h2><span class="glyphicons_v2 circle-alert invert svg"></span> #= title #</h2>
#           # if (message instanceof Array) { #
#             <ul>
#               # for (var i = 0; i < message.length; i++) { #
#                 <li>#= message[i] #</li>
#               # } #
#             </ul>
#           # } else { #
#             <p>#= message #</p>
#           # } #
#         </span>
#       </div>
#   </script>
#   <script id="successTemplate" type="text/x-kendo-template">
#    <div class="notification success">
#         <span>
#           <h2><span class="glyphicons_v2 circle-check invert svg"></span> #= title #</h2>
#           <p>#= message #</p>
#         </span>
#       </div>
#   </script>
#   <script id="network_combo_template" type="text/x-kendo-tmpl">
#    <span class="k-state-default image">
#         # if (data.logo_path) { #
#           <img src="https://media.themoviedb.org/t/p/h15${data.logo_path}" alt="${data.name}" srcset="https://media.themoviedb.org/t/p/h15${data.logo_path} 1x, https://media.themoviedb.org/t/p/h30${data.logo_path} 2x" height="15">&nbsp;&nbsp;-&nbsp;
#         # } #
#         ${data.name}# if (data.origin_country) { # (${data.origin_country}) # } #
#       </span>
#   </script>
#   <script type="application/ld+json">
#    {
#         "@context": "http://schema.org",
#         "@type": "WebSite",
#         "name": "The Movie Database",
#         "alternateName": "TMDB",
#         "url": "https://www.themoviedb.org"
#       }
#   </script>
#   <script type="application/ld+json">
#    {
#          "@context": "http://schema.org",
#          "@type": "WebSite",
#          "url": "https://www.themoviedb.org/",
#          "potentialAction": {
#            "@type": "SearchAction",
#            "target": "https://www.themoviedb.org/search?query={search_term_string}",
#            "query-input": "required name=search_term_string"
#          }
#       }
#   </script>
#  </body>
# </html>

# %%
people_content.find('title').text
# Out:
# 'Popular People — The Movie Database (TMDB)'

# %% [markdown]
# Test case 2: Non-working URL

# %%
gibberish_url='https://www.themoviedb.org/personhelloxyz'
html_content=get_webpage_source(gibberish_url)
# Out:
# Error :  404 Client Error: Not Found for url: https://www.themoviedb.org/personhelloxyz

# %% [markdown]
# 3) Extract the content of the webpage - https://www.themoviedb.org/movie - that hosts a current dated listing of popular movies

# %%
movie_url='https://www.themoviedb.org/movie'
movie_content=get_webpage_source(movie_url)
print(movie_content.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
#  <head>
#   <title>
#    Popular Movies — The Movie Database (TMDB)
#   </title>
#   <meta content="on" http-equiv="cleartype"/>
#   <meta charset="utf-8"/>
#   <meta content="Movies, TV Shows, Streaming, Reviews, API, Actors, Actresses, Photos, User Ratings, Synopsis, Trailers, Teasers, Credits, Cast" name="keywords"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="The Movie Database (TMDB) is a popular, user editable database for movies and TV shows." name="description"/>
#   <meta content="/assets/2/v4/icons/mstile-144x144-30e7905a8315a080978ad6aeb71c69222b72c2f75d26dab1224173a96fecc962.png" name="msapplication-TileImage"/>
#   <meta content="#032541" name="msapplication-TileColor"/>
#   <meta content="#032541" name="theme-color"/>
#   <link href="/assets/2/apple-touch-icon-57ed4b3b0450fd5e9a0c20f34e814b82adaa1085c79bdde2f00ca8787b63d2c4.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/assets/2/favicon-32x32-543a21832c8931d3494a68881f6afcafc58e96c5d324345377f3197a37b367b5.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/assets/2/favicon-16x16-b362d267873ce9c5a39f686a11fe67fec2a72ed25fa8396c11b71aa43c938b11.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/manifest.json?version=3" rel="manifest"/>
#   <link href="https://www.themoviedb.org/movie" rel="canonical"/>
#   <link href="/opensearch.xml" rel="search" title="TMDB Search" type="application/opensearchdescription+xml"/>
#   <link as="font" crossorigin="" href="/assets/2/Consensus-3cba2c4d050ea63dbf7783173d288faf9ecb2942515a5e7f6e1beecabb2eaf72.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-regular-f38472b9e378b8c936f55a92677f575ab69e414d7cc3706ecfefeacd994b7975.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-italic-48273a74acbc1611b6ef1d0a771bb8ef042b9922b51d5bff560571dddcb5542a.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-300-db9f15a13a9f8b8bc46db7756ab863e8834bd20a7a1124c4c0a5a8f7892f3e99.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-600-6a087a74d78fc7d7b97fa1b0911c4ff3be4ff0bd5144618fd7ddc63ef1777f3a.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-700-d67f7dff97d105f4ac5616b00fc7822ce2c33f653ece2f547995e6a71bb7b993.woff2" rel="preload" type="font/woff2"/>
#   <link href="/assets/2/v4/fonts-b603098c04ec971699962bc88ab333f4df4df8f98479bf1d0e826744167c6b41.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/2/application-4d1a86bac309736e9d1f2cf5cfbdcbc398bef8ebf96493822b861c03d8e85bd3.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/2/v4/media-ca37a789e45c1f0501ae4e046f437f5443d2e496e551111e61f3bd1e5d2701b3.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/2/v4/discover-b2c3bb76e3d2b2323e842dc4be56a342c51e08c3bb91c6a010e8b401b180f117.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/2/v4/account-767bb35541426b4fb018609f25f0fb53ac8137804b56d3e99380c6d3d07c1fc6.css" media="screen" rel="stylesheet"/>
#   <link href="https://www.themoviedb.org/movie" hreflang="x-default" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=af-ZA" hreflang="af-ZA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ar-SA" hreflang="ar-SA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=be-BY" hreflang="be-BY" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=bg-BG" hreflang="bg-BG" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=bn-BD" hreflang="bn-BD" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ca-ES" hreflang="ca-ES" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ch-GU" hreflang="ch-GU" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=cn-CN" hreflang="cn-CN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=cs-CZ" hreflang="cs-CZ" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=cy-GB" hreflang="cy-GB" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=da-DK" hreflang="da-DK" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=de-DE" hreflang="de-DE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=el-GR" hreflang="el-GR" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-US" hreflang="en-US" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=eo-EO" hreflang="eo-EO" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=es-ES" hreflang="es-ES" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=et-EE" hreflang="et-EE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=eu-ES" hreflang="eu-ES" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=fa-IR" hreflang="fa-IR" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=fi-FI" hreflang="fi-FI" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=fr-FR" hreflang="fr-FR" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ga-IE" hreflang="ga-IE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=gd-GB" hreflang="gd-GB" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=gl-ES" hreflang="gl-ES" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=he-IL" hreflang="he-IL" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=hi-IN" hreflang="hi-IN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=hr-HR" hreflang="hr-HR" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=hu-HU" hreflang="hu-HU" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=id-ID" hreflang="id-ID" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=it-IT" hreflang="it-IT" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ja-JP" hreflang="ja-JP" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ka-GE" hreflang="ka-GE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=kk-KZ" hreflang="kk-KZ" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=kn-IN" hreflang="kn-IN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ko-KR" hreflang="ko-KR" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ky-KG" hreflang="ky-KG" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=lt-LT" hreflang="lt-LT" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=lv-LV" hreflang="lv-LV" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ml-IN" hreflang="ml-IN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=mr-IN" hreflang="mr-IN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ms-MY" hreflang="ms-MY" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=nb-NO" hreflang="nb-NO" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=nl-NL" hreflang="nl-NL" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=no-NO" hreflang="no-NO" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=pa-IN" hreflang="pa-IN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=pl-PL" hreflang="pl-PL" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=pt-PT" hreflang="pt-PT" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ro-RO" hreflang="ro-RO" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ru-RU" hreflang="ru-RU" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=si-LK" hreflang="si-LK" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=sk-SK" hreflang="sk-SK" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=sl-SI" hreflang="sl-SI" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=sq-AL" hreflang="sq-AL" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=sr-RS" hreflang="sr-RS" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=sv-SE" hreflang="sv-SE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=sw-TZ" hreflang="sw-TZ" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ta-IN" hreflang="ta-IN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=te-IN" hreflang="te-IN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=tl-PH" hreflang="tl-PH" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=th-TH" hreflang="th-TH" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=tr-TR" hreflang="tr-TR" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=uk-UA" hreflang="uk-UA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ur-PK" hreflang="ur-PK" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=vi-VN" hreflang="vi-VN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=zh-CN" hreflang="zh-CN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=zu-ZA" hreflang="zu-ZA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ar-AE" hreflang="ar-AE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ar-BH" hreflang="ar-BH" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ar-EG" hreflang="ar-EG" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ar-IQ" hreflang="ar-IQ" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ar-JO" hreflang="ar-JO" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ar-LY" hreflang="ar-LY" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ar-MA" hreflang="ar-MA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ar-QA" hreflang="ar-QA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ar-YE" hreflang="ar-YE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ar-TD" hreflang="ar-TD" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ca-AD" hreflang="ca-AD" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=de-AT" hreflang="de-AT" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=de-CH" hreflang="de-CH" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=el-CY" hreflang="el-CY" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-AG" hreflang="en-AG" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-AU" hreflang="en-AU" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-BB" hreflang="en-BB" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-BZ" hreflang="en-BZ" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-CA" hreflang="en-CA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-CM" hreflang="en-CM" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-GB" hreflang="en-GB" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-GG" hreflang="en-GG" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-GH" hreflang="en-GH" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-GI" hreflang="en-GI" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-GY" hreflang="en-GY" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-IE" hreflang="en-IE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-JM" hreflang="en-JM" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-KE" hreflang="en-KE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-LC" hreflang="en-LC" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-MW" hreflang="en-MW" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-NZ" hreflang="en-NZ" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-PG" hreflang="en-PG" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-TC" hreflang="en-TC" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-ZM" hreflang="en-ZM" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=en-ZW" hreflang="en-ZW" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=es-AR" hreflang="es-AR" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=es-CL" hreflang="es-CL" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=es-DO" hreflang="es-DO" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=es-EC" hreflang="es-EC" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=es-GT" hreflang="es-GT" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=es-GQ" hreflang="es-GQ" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=es-HN" hreflang="es-HN" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=es-MX" hreflang="es-MX" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=es-NI" hreflang="es-NI" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=es-PA" hreflang="es-PA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=es-PE" hreflang="es-PE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=es-PY" hreflang="es-PY" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=es-SV" hreflang="es-SV" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=es-UY" hreflang="es-UY" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=fr-BF" hreflang="fr-BF" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=fr-CA" hreflang="fr-CA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=fr-CD" hreflang="fr-CD" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=fr-CI" hreflang="fr-CI" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=fr-GF" hreflang="fr-GF" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=fr-GP" hreflang="fr-GP" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=fr-MC" hreflang="fr-MC" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=fr-ML" hreflang="fr-ML" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=fr-MU" hreflang="fr-MU" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=fr-PF" hreflang="fr-PF" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=it-VA" hreflang="it-VA" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ms-SG" hreflang="ms-SG" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=nl-BE" hreflang="nl-BE" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=pt-AO" hreflang="pt-AO" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=pt-BR" hreflang="pt-BR" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=pt-MZ" hreflang="pt-MZ" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=ro-MD" hreflang="ro-MD" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=sr-ME" hreflang="sr-ME" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=sq-XK" hreflang="sq-XK" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=zh-HK" hreflang="zh-HK" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=zh-SG" hreflang="zh-SG" rel="alternate"/>
#   <link href="https://www.themoviedb.org/movie?language=zh-TW" hreflang="zh-TW" rel="alternate"/>
#   <script charset="UTF-8" data-domain-script="23223fbb-5c84-48df-836d-0a83fb7b2c03" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript">
#   </script>
#   <script>
#    function OptanonWrapper() {}
#   </script>
#   <script src="/assets/2/lozad.min-7f803337d01a657607bca6b20e06f371c3895b36a5f2be03a8fa9b5e16c9a83e.js">
#   </script>
#   <script src="/assets/2/jquery-3.6.0.min-ff1523fb7389539c84c65aba19260648793bb4f5e29329d2ee8804bc37a3fe6e.js">
#   </script>
#   <script>
#    $(function() {
#         jQuery.event.special.touchstart = {
#           setup: function(_, ns, handle) {
#             this.addEventListener("touchstart", handle, { passive: !ns.includes("noPreventDefault") });
#           }
#         };
#         jQuery.event.special.touchmove = {
#           setup: function(_, ns, handle) {
#             this.addEventListener("touchmove", handle, { passive: !ns.includes("noPreventDefault") });
#           }
#         };
#       });
#       detected_timezone = Intl.DateTimeFormat().resolvedOptions().timeZone;
#         timezone = detected_timezone;
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-5QWVXV');
#   </script>
#   <script src="/assets/2/kendo-93daa31ab3dcca8723478255a3b3c3f0a9e6672dddc612e114391786423c1870.js">
#   </script>
#   <script src="/assets/2/kendo-2021.1.204/cultures/kendo.culture.en-US.min-61ce5636474a35333ecff74fe30c528d459bcee29b3b32fc0c58ac77de788b34.js">
#   </script>
#   <script>
#    kendo.culture("en-US");
#   </script>
#   <script src="/assets/2/kendo-2021.1.204/messages/kendo.messages.en-US.min-79da68ae0221b4fd7978805d0c79cc7f682fddace5f2137aa0dae8fe1c5ddacd.js">
#   </script>
#   <script src="/assets/2/application-a005f527fa2f63db2e7eb7124265a53965cb0ab5268caebc32c41305b4da51b1.js">
#   </script>
#   <script src="/assets/2/pusher.min-ee61b1e19799dd5aae92a3d91bc970e6147c6fe4395eacf3e499ed1451650f22.js">
#   </script>
#   <script defer="" src="/assets/2/application.desktop-ea69249141a43ef7c6a59a19ee40eface5e171cf03eefffddb488574a66dea02.js">
#   </script>
#   <script defer="" src="/assets/2/kendo-2021.1.204/kendo.calendar.min-ff597f14a778b702ec1cf9967dec754e429caf1558c8b89f0de036e8efe39761.js">
#   </script>
#   <script defer="" src="/assets/2/kendo-2021.1.204/kendo.datepicker.min-9efa21cba900555da428262129f44042706c5abac5644c872d9cac78f010493a.js">
#   </script>
#   <script defer="" src="/assets/2/kendo-2021.1.204/kendo.slider.min-1e770b8fc7facf8ee48d3b0ad7abdfb598ab17cb69add240accc8df5fa2bc919.js">
#   </script>
#  </head>
#  <body class="en v4">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5QWVXV" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div class="page_wrap movie_wrap">
#    <header class="normal smaller no_animation smaller subtle">
#     <div class="content">
#      <div class="sub_media">
#       <div class="nav_wrapper">
#        <a class="logo" href="/">
#         <img alt="The Movie Database (TMDB)" height="20" src="/assets/2/v4/logos/v2/blue_short-8e7b30f73a4020692ccca9c88bafe5dcb6f8a62a4c6bc55cd9ba82bb2cd95f6c.svg" width="154"/>
#        </a>
#        <ul class="dropdown_menu navigation">
#         <li>
#          <a class="no_click" href="/movie">
#           Movies
#          </a>
#          <ul>
#           <li>
#            <a href="/movie">
#             Popular
#            </a>
#           </li>
#           <li>
#            <a href="/movie/now-playing">
#             Now Playing
#            </a>
#           </li>
#           <li>
#            <a href="/movie/upcoming">
#             Upcoming
#            </a>
#           </li>
#           <li>
#            <a href="/movie/top-rated">
#             Top Rated
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="no_click" href="/tv">
#           TV Shows
#          </a>
#          <ul>
#           <li>
#            <a href="/tv">
#             Popular
#            </a>
#           </li>
#           <li>
#            <a href="/tv/airing-today">
#             Airing Today
#            </a>
#           </li>
#           <li>
#            <a href="/tv/on-the-air">
#             On TV
#            </a>
#           </li>
#           <li>
#            <a href="/tv/top-rated">
#             Top Rated
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="no_click" href="/person">
#           People
#          </a>
#          <ul>
#           <li>
#            <a href="/person">
#             Popular People
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="no_click" href="#">
#           More
#          </a>
#          <ul>
#           <li>
#            <a href="/discuss">
#             Discussions
#            </a>
#           </li>
#           <li>
#            <a href="/leaderboard">
#             Leaderboard
#            </a>
#           </li>
#           <li>
#            <a href="/talk">
#             Support
#            </a>
#           </li>
#           <li>
#            <a href="https://developer.themoviedb.org/docs" target="_blank">
#             API
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </div>
#       <div class="flex">
#        <ul class="primary">
#         <li class="glyph new_buttons">
#          <a class="new_icon no_click" href="#">
#           <span class="glyphicons_v2 plus white">
#           </span>
#          </a>
#         </li>
#         <li class="translate">
#          <div>
#           en
#          </div>
#         </li>
#         <li>
#          <a href="/login">
#           Login
#          </a>
#         </li>
#         <li>
#          <a href="/signup">
#           Join TMDB
#          </a>
#         </li>
#         <li class="glyph search_buttons">
#          <a class="search" href="/search">
#           <span class="glyphicons_v2 search blue">
#           </span>
#          </a>
#          <a class="close hide" href="/search">
#           <span class="glyphicons_v2 menu-close invert svg">
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="search_bar hide">
#      <section class="search show_search_false">
#       <div class="sub_media">
#        <form accept-charset="utf-8" action="/search" id="search_form" method="get">
#         <label>
#          <input autocomplete="off" autocorrect="off" autofill="off" dir="auto" id="search_v4" name="query" placeholder="Search for a movie, tv show, person..." spellcheck="false" tabindex="1" type="text" value=""/>
#         </label>
#         <input disabled="" type="submit"/>
#        </form>
#       </div>
#      </section>
#     </div>
#    </header>
#    <main class="smaller subtle show_search_false" id="main">
#     <section class="inner_content">
#      <div class="media discover" id="media_v4">
#       <div class="column_wrapper">
#        <div class="content_wrapper">
#         <div class="title">
#          <h2>
#           Popular Movies
#          </h2>
#         </div>
#         <div class="content">
#          <div class="">
#           <div class="filter_panel card closed">
#            <div class="name">
#             <h2>
#              Sort
#             </h2>
#             <span class="glyphicons_v2 chevron-right">
#             </span>
#            </div>
#            <div class="filter">
#             <h3>
#              Sort Results By
#             </h3>
#             <select class="kendo_dropdown full_width font_size_1" id="sort_by" name="sort_by">
#              <option selected="" value="popularity.desc">
#               Popularity Descending
#              </option>
#              <option value="popularity.asc">
#               Popularity Ascending
#              </option>
#              <option value="vote_average.desc">
#               Rating Descending
#              </option>
#              <option value="vote_average.asc">
#               Rating Ascending
#              </option>
#              <option value="primary_release_date.desc">
#               Release Date Descending
#              </option>
#              <option value="primary_release_date.asc">
#               Release Date Ascending
#              </option>
#              <option value="title.asc">
#               Title (A-Z)
#              </option>
#              <option value="title.desc">
#               Title (Z-A)
#              </option>
#             </select>
#            </div>
#           </div>
#           <div class="filter_panel card closed">
#            <div class="name">
#             <h2>
#              Where To Watch
#              <span>
#               62
#              </span>
#             </h2>
#             <span class="glyphicons_v2 chevron-right">
#             </span>
#            </div>
#            <div class="filter">
#             <h3>
#              My Services
#              <span class="tooltip glyphicons_v2 circle-question" data-tooltip-id="#ott_tooltip">
#              </span>
#             </h3>
#             <label class="k-form-field">
#              <input class="k-checkbox" disabled="" id="my_services" name="my_services" type="checkbox" value="true"/>
#              <label class="k-checkbox-label" for="my_services">
#               Restrict searches to my subscribed services?
#              </label>
#             </label>
#            </div>
#            <div class="filter">
#             <h3>
#              Country
#             </h3>
#             <div class="font_size_1 kendo_dropdown" id="watch_region" style="width: 100%;">
#             </div>
#             <span id="ott_provider_wrapper">
#              <ul class="ott_providers multi_select image" id="ott_providers" style="margin-bottom: 0;">
#               <li class="" data-value="8">
#                <a class="no_click" href="#" title="Netflix">
#                 <img alt="Netflix" height="50" src="https://media.themoviedb.org/t/p/original/pbpMk2JmcoNnQwx5JGpXngfoWtp.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="119">
#                <a class="no_click" href="#" title="Amazon Prime Video">
#                 <img alt="Amazon Prime Video" height="50" src="https://media.themoviedb.org/t/p/original/dQeAar5H991VYporEjUspolDarG.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="350">
#                <a class="no_click" href="#" title="Apple TV Plus">
#                 <img alt="Apple TV Plus" height="50" src="https://media.themoviedb.org/t/p/original/2E03IAZsX4ZaUqM7tXlctEPMGWS.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="2">
#                <a class="no_click" href="#" title="Apple TV">
#                 <img alt="Apple TV" height="50" src="https://media.themoviedb.org/t/p/original/9ghgSC0MA082EL6HLCW3GalykFD.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="283">
#                <a class="no_click" href="#" title="Crunchyroll">
#                 <img alt="Crunchyroll" height="50" src="https://media.themoviedb.org/t/p/original/mXeC4TrcgdU6ltE9bCBCEORwSQR.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="122">
#                <a class="no_click" href="#" title="Hotstar">
#                 <img alt="Hotstar" height="50" src="https://media.themoviedb.org/t/p/original/zdTSUEVZFXp3E0EkOMGN99QPVJp.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="121">
#                <a class="no_click" href="#" title="Voot">
#                 <img alt="Voot" height="50" src="https://media.themoviedb.org/t/p/original/1uQBlkLRe04k58L8q1IrYOYvGfk.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="220">
#                <a class="no_click" href="#" title="Jio Cinema">
#                 <img alt="Jio Cinema" height="50" src="https://media.themoviedb.org/t/p/original/AsPkPqjTut1gV4OhWW3hChwTOXE.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="232">
#                <a class="no_click" href="#" title="Zee5">
#                 <img alt="Zee5" height="50" src="https://media.themoviedb.org/t/p/original/vPIW5b0ebTLj9bFCZypoBbF8wSl.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="218">
#                <a class="no_click" href="#" title="Eros Now">
#                 <img alt="Eros Now" height="50" src="https://media.themoviedb.org/t/p/original/ouJUBLjxevh4UaEGV4ZUjsSWdRq.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="3">
#                <a class="no_click" href="#" title="Google Play Movies">
#                 <img alt="Google Play Movies" height="50" src="https://media.themoviedb.org/t/p/original/8z7rC8uIDaTM91X0ZfkRf04ydj2.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="11">
#                <a class="no_click" href="#" title="MUBI">
#                 <img alt="MUBI" height="50" src="https://media.themoviedb.org/t/p/original/fj9Y8iIMFUC6952HwxbGixTQPb7.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="237">
#                <a class="no_click" href="#" title="Sony Liv">
#                 <img alt="Sony Liv" height="50" src="https://media.themoviedb.org/t/p/original/3973zlBbBXdXxaWqRWzGG2GYxbT.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="192">
#                <a class="no_click" href="#" title="YouTube">
#                 <img alt="YouTube" height="50" src="https://media.themoviedb.org/t/p/original/pTnn5JwWr4p3pG8H6VrpiQo7Vs0.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="100">
#                <a class="no_click" href="#" title="GuideDoc">
#                 <img alt="GuideDoc" height="50" src="https://media.themoviedb.org/t/p/original/eKVmLFHW5PeNhuR7Nedd8OIxW2M.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="175">
#                <a class="no_click" href="#" title="Netflix Kids">
#                 <img alt="Netflix Kids" height="50" src="https://media.themoviedb.org/t/p/original/kwVegvKCinXTPuzZmYT1J3i1HJz.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="73">
#                <a class="no_click" href="#" title="Tubi TV">
#                 <img alt="Tubi TV" height="50" src="https://media.themoviedb.org/t/p/original/o4JMLTkDfjei1XrsVk1vSjXfdBk.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="255">
#                <a class="no_click" href="#" title="Yupp TV">
#                 <img alt="Yupp TV" height="50" src="https://media.themoviedb.org/t/p/original/6msAJGK2yF39S2PGrinWiVCNmJn.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="309">
#                <a class="no_click" href="#" title="Sun Nxt">
#                 <img alt="Sun Nxt" height="50" src="https://media.themoviedb.org/t/p/original/6KEQzITx2RrCAQt5Nw9WrL1OI8z.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="315">
#                <a class="no_click" href="#" title="Hoichoi">
#                 <img alt="Hoichoi" height="50" src="https://media.themoviedb.org/t/p/original/u7dwMceEbjxd1N3TLEUBILSK2x6.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="437">
#                <a class="no_click" href="#" title="Hungama Play">
#                 <img alt="Hungama Play" height="50" src="https://media.themoviedb.org/t/p/original/pMTVKAUyjMb0xdMnHqfNj73MGH6.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="319">
#                <a class="no_click" href="#" title="Alt Balaji">
#                 <img alt="Alt Balaji" height="50" src="https://media.themoviedb.org/t/p/original/i7knsL0QgDJyuts5FbfjREUqHvu.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="190">
#                <a class="no_click" href="#" title="Curiosity Stream">
#                 <img alt="Curiosity Stream" height="50" src="https://media.themoviedb.org/t/p/original/oR1aNm1Qu9jQBkW4VrGPWhqbC3P.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="476">
#                <a class="no_click" href="#" title="EPIC ON">
#                 <img alt="EPIC ON" height="50" src="https://media.themoviedb.org/t/p/original/ymlo2k6RlX0zF5Te1AYwXRQ7Pra.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="474">
#                <a class="no_click" href="#" title="ShemarooMe">
#                 <img alt="ShemarooMe" height="50" src="https://media.themoviedb.org/t/p/original/ec3kgfQ6YXbT3AFRh8bkQZQFLb2.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="502">
#                <a class="no_click" href="#" title="Tata Play">
#                 <img alt="Tata Play" height="50" src="https://media.themoviedb.org/t/p/original/5VLMQDq6LWfftQCl7sYrtTseXRA.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="510">
#                <a class="no_click" href="#" title="Discovery+">
#                 <img alt="Discovery+" height="50" src="https://media.themoviedb.org/t/p/original/eMTnWwNVtThkjvQA6zwxaoJG9NE.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="482">
#                <a class="no_click" href="#" title="ManoramaMax">
#                 <img alt="ManoramaMax" height="50" src="https://media.themoviedb.org/t/p/original/tFkqZYsDhNe6hJCx50Aw6oma24w.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="471">
#                <a class="no_click" href="#" title="FILMRISE">
#                 <img alt="FILMRISE" height="50" src="https://media.themoviedb.org/t/p/original/iS5NCgmSqTnkNoTQY8nBvSZsEnF.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="515">
#                <a class="no_click" href="#" title="MX Player">
#                 <img alt="MX Player" height="50" src="https://media.themoviedb.org/t/p/original/ayHY6wKxvCKj2PU8eRPFxnPc6B0.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="521">
#                <a class="no_click" href="#" title="Spamflix">
#                 <img alt="Spamflix" height="50" src="https://media.themoviedb.org/t/p/original/k2YgZyxij5RcnS1qqUYEUrJB4oQ.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="532">
#                <a class="no_click" href="#" title="aha">
#                 <img alt="aha" height="50" src="https://media.themoviedb.org/t/p/original/8WerMI8XcZXqPpkHTZNtzMzousF.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="545">
#                <a class="no_click" href="#" title="Spuul">
#                 <img alt="Spuul" height="50" src="https://media.themoviedb.org/t/p/original/iAHIvSg9jlXIvOR1NONjN5CsU3l.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="538">
#                <a class="no_click" href="#" title="Plex">
#                 <img alt="Plex" height="50" src="https://media.themoviedb.org/t/p/original/vLZKlXUNDcZR7ilvfY9Wr9k80FZ.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="546">
#                <a class="no_click" href="#" title="WOW Presents Plus">
#                 <img alt="WOW Presents Plus" height="50" src="https://media.themoviedb.org/t/p/original/6dET59jNU0ADysghEjl8Unuc7Ca.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="551">
#                <a class="no_click" href="#" title="Magellan TV">
#                 <img alt="Magellan TV" height="50" src="https://media.themoviedb.org/t/p/original/mSH24WQcRDJ2fsL5iucXqqRnSRb.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="554">
#                <a class="no_click" href="#" title="BroadwayHD">
#                 <img alt="BroadwayHD" height="50" src="https://media.themoviedb.org/t/p/original/6IYZ4NjwPikxN7J9cfSmuyeHeMm.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="559">
#                <a class="no_click" href="#" title="Filmzie">
#                 <img alt="Filmzie" height="50" src="https://media.themoviedb.org/t/p/original/eUBxtrqO26wAJfYOZJOzhQEo3mm.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="561">
#                <a class="no_click" href="#" title="Lionsgate Play">
#                 <img alt="Lionsgate Play" height="50" src="https://media.themoviedb.org/t/p/original/4P963etfZGzeJqqd6E8fj2OIUht.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="562">
#                <a class="no_click" href="#" title="MovieSaints">
#                 <img alt="MovieSaints" height="50" src="https://media.themoviedb.org/t/p/original/9vMVMnVnWwxt0TkCazKLYW1zuqY.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="444">
#                <a class="no_click" href="#" title="Dekkoo">
#                 <img alt="Dekkoo" height="50" src="https://media.themoviedb.org/t/p/original/x6nRFzF32hCzMHaVM4RHRo7lsgS.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="567">
#                <a class="no_click" href="#" title="True Story">
#                 <img alt="True Story" height="50" src="https://media.themoviedb.org/t/p/original/aRPDQvVcpeY07sjI6lAALMCL0ti.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="569">
#                <a class="no_click" href="#" title="DocAlliance Films">
#                 <img alt="DocAlliance Films" height="50" src="https://media.themoviedb.org/t/p/original/vbXJBJVv3u3YWt6ml0l0ldDblXT.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="614">
#                <a class="no_click" href="#" title="VI movies and tv">
#                 <img alt="VI movies and tv" height="50" src="https://media.themoviedb.org/t/p/original/1tCAM3WVOl0xknuwVc0v1LBWZNV.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="677">
#                <a class="no_click" href="#" title="Eventive">
#                 <img alt="Eventive" height="50" src="https://media.themoviedb.org/t/p/original/fwx5Ed64TkfWiRH1SOSkc4781Ts.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="688">
#                <a class="no_click" href="#" title="ShortsTV Amazon Channel">
#                 <img alt="ShortsTV Amazon Channel" height="50" src="https://media.themoviedb.org/t/p/original/2nFBw1zMzN1AujFaCsmsgSKWdfS.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="10">
#                <a class="no_click" href="#" title="Amazon Video">
#                 <img alt="Amazon Video" height="50" src="https://media.themoviedb.org/t/p/original/seGSXajazLMCKGB5hnRCidtjay1.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="692">
#                <a class="no_click" href="#" title="Cultpix">
#                 <img alt="Cultpix" height="50" src="https://media.themoviedb.org/t/p/original/uauVx3dGWt0GICqdMCBYJObd3Mo.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="701">
#                <a class="no_click" href="#" title="FilmBox+">
#                 <img alt="FilmBox+" height="50" src="https://media.themoviedb.org/t/p/original/fbveJTcro9Xw2KuPIIoPPePHiwy.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="528">
#                <a class="no_click" href="#" title="AMC+ Amazon Channel">
#                 <img alt="AMC+ Amazon Channel" height="50" src="https://media.themoviedb.org/t/p/original/2ino0WmHA4GROB7NYKzT6PGqLcb.jpg" width="50"/>
#                 <div>
#                  <span class="glyphicons_v2 check white">
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <li class="" data-value="196">
#                <a class="no_click" href="#" title="AcornTV Amazon Channel">
# ...
#           dataTextField: "title",
#           template: kendo.template($("#slim_multi_search_template").html()),
#           noDataTemplate: $("#search_no_data_template").html(),
#           dataSource: {
#             type: "json",
#             serverFiltering: true,
#             transport: {
#               read: '/search/trending',
#               parameterMap: function() {
#                 return { query: $("#search_v4").data("kendoAutoComplete").value() };
#               }
#             },
#             schema: {
#               data: "results"
#             }
#           },
#           popup: {
#             appendTo: $("header")
#           },
#           filtering: function(e) {
#             var filter = e.filter != undefined ? e.filter.value : "";
#             if (filter == '') {
#               if ( ($('#search_v4-list #trending_search_header_template').length) == 0 ) {
#                 // $('#search_v4_listbox').empty();
#                 $('#search_v4-list').prepend($("#search_v4_headerTemplate").html());
#               }
#             } else {
#               $("#trending_search_header_template").remove();
#             }
#           },
#           select: function(e) {
#             processing_selected_item = true;
#             processSelectedItem(e);
#           },
#           close: function(e) {
#             // e.preventDefault();
#           }
#         }).data("kendoAutoComplete");
#
#         $('#search_v4').keydown(function(event) {
#           if (event.keyCode == 13) {
#             if (processing_selected_item) {
#               return;
#             } else {
#               processSelectedItem(null);
#             }
#           }
#         });
#
#         $('header #search_form').submit(function() {
#           return false;
#         });
#
#         var autocompleteInput = $('section.search .k-autocomplete input');
#         autocompleteInput.on('focus', function (e) {
#           var value = autocompleteInput.val();
#           if (value == null || value == '') {
#             $("#search_v4").data("kendoAutoComplete").search('');
#           } else {
#             var fieldLength = value.length;
#             autocompleteInput[0].setSelectionRange(fieldLength, fieldLength);
#           }
#         });
#
#         $('li.search_buttons a.search').on('click', function(e) {
#           e.preventDefault();
#           showSearch(true);
#         });
#
#         $('li.search_buttons a.close').on('click', function(e) {
#           e.preventDefault();
#           showSearch(false);
#         });
#
#         $('main.show_search_false').on('click', function(e) {
#           showSearch(false);
#         });
#
#         $('header span.k-i-close[title="clear"]').on('click', function(e) {
#           $('#search_v4').data("kendoAutoComplete").focus();
#         });
#
#
#         public_media_type_map = { 'movie': 'Movie', 'tv': 'TV Show', 'person': 'Person' };
#
#
#         $(document).on('keydown', null, 'b', function() {
#           if ( $('a.keyboard_s.parent').length ) {
#             $('a.keyboard_s.parent')[0].click();
#           }
#         });
#
#         $(document).on('keyup', null, 's', function() {
#           if ( $('#search_v4').length ) {
#             showSearch(true);
#           }
#         });
#
#         $(document).on('keyup', null, 'shift+/', function() {
#           keyboard_shortcut_popup.open();
#         });
#
#         $(document).on('keydown', null, 'left', function() {
#           if ( $('span.previous a.keyboard_s').length ) {
#             $('span.previous a.keyboard_s')[0].click();
#           }
#         });
#
#         $(document).on('keydown', null, 'right', function() {
#           if ( $('span.next a.keyboard_s').length ) {
#             $('span.next a.keyboard_s')[0].click();
#           }
#         });
#
#         $(document).on('keydown', null, 'm', function() {
#           if ( $('#new_shortcut_bar').length ) {
#             $("#new_shortcut_bar").focus();
#           }
#         });
#
#         $(document).on('keydown', null, 'esc', function() {
#           if ( $('div.custom_bg.keyboard_s').length && $('#ott_offers_window a.close').length ) {
#             $('#ott_offers_window a.close')[0].click();
#           }
#         });
#       });
#
#       var gender_lookup = {
#         0: 'two',
#         1: 'one',
#         2: 'two',
#         3: 'two'
#       }
#   </script>
#   <script id="person_template" type="text/x-kendo-tmpl">
#    <div class="item profile list_item grid_item">
#         <div class="image_content profile">
#           <a class="result" href="/person/${data.url}" title="${data.name}" alt="${data.name}">
#             # if (data.profile_path) { #
#               <img class="" src="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path}" alt="${data.name}" width="45" height="45" srcset="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path} 1x, https://media.themoviedb.org/t/p/w132_and_h132_face${data.profile_path} 2x">
#             # } else { #
#               <div class="glyphicons_v2 picture profile ${gender_lookup[data.gender]} grey no_image_holder w45_and_h45"></div>
#             # } #
#           </a>
#         </div>
#
#         <div class="content">
#           <p class="name"><a class="result" href="/person/${data.url}" title="${data.name}" alt="${data.name}">${data.name}</a></p>
#
#           # if (data.known_for) { #
#             <p class="sub">${data.known_for}</p>
#           # } #
#         </div>
#       </div>
#   </script>
#   <script id="person_template_with_known_for" type="text/x-kendo-tmpl">
#    <div class="item profile list_item known_for">
#         <div class="image_content profile">
#           # if (data.profile_path) { #
#             <img class="" src="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path}" alt="${data.name}" width="45" height="45" srcset="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path} 1x, https://media.themoviedb.org/t/p/w132_and_h132_face${data.profile_path} 2x">
#           # } else { #
#             <div class="glyphicons_v2 picture grey no_image_holder w45_and_h45 profile"></div>
#           # } #
#         </div>
#
#         <div class="content">
#           <p class="name">${data.name}</p>
#           # if (data.known_for) { #
#             <p class="sub">${data.known_for_department} &bull; ${data.known_for}</p>
#           # } else { #
#             <p class="sub">No known credits.</p>
#           # } #
#         </div>
#       </div>
#   </script>
#   <script id="person_result_template" type="text/x-kendo-tmpl">
#    <div class="ac_item profile list_item known_for">
#         <div class="image_content profile">
#           # if (data.profile_path) { #
#             <img class="" src="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path}" alt="${data.name}" width="45" height="45" srcset="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path} 1x, https://media.themoviedb.org/t/p/w132_and_h132_bestv2${data.profile_path} 2x">
#           # } else { #
#             <div class="glyphicons_v2 picture grey no_image_holder w45_and_h45 profile"></div>
#           # } #
#         </div>
#
#         <div class="content">
#           <p class="name">${data.name}</p>
#           # if (data.known_for) { #
#             <p class="sub">
#               # if (data.media_type) { #
#                 <span class="media_type person">#= public_media_type_map[data.media_type] # &bull; </span>
#               # } #
#               # for (var i = 0; i < data.known_for.length; i++) { #
#               <span class="comma">#= data.known_for[i].title ? data.known_for[i].title : data.known_for[i].name #</span>
#               # } #
#             </p>
#           # } else { #
#             <p class="sub">No known credits.</p>
#           # } #
#         </div>
#       </div>
#   </script>
#   <script id="movie_result_template" type="text/x-kendo-tmpl">
#    <div class="ac_results">
#         <div class="ac_item poster list_item">
#           <div class="image_content poster">
#             # if (data.poster_path) { #
#               <img class="" src="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path}" alt="${data.title}" width="45" height="67" srcset="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path} 1x, https://media.themoviedb.org/t/p/w90_and_h134_bestv2${data.poster_path} 2x">
#             # } else { #
#               <div class="glyphicons_v2 picture grey no_image_holder w45_and_h67"></div>
#             # } #
#           </div>
#
#           <div class="content">
#             <p class="name">${data.title}</p>
#             <p class="sub">
#               # if (data.media_type) { #
#                 <span class="media_type movie">#= public_media_type_map[data.media_type] # &bull; </span>
#               # } #
#               # if (data.original_title !== data.title) { #
#                 <span class="comma"><span class="original_title">#= data.original_title #</span></span>
#               # } #
#               # if (data.release_date) { #
#                 <span class="comma"><span class="release_date">#= data.release_date #</span></span>
#               # } #
#             </p>
#           </div>
#         </div>
#       </div>
#   </script>
#   <script id="tv_show_result_template" type="text/x-kendo-tmpl">
#    <div class="ac_item poster list_item">
#         <div class="image_content poster">
#           # if (data.poster_path) { #
#             <img class="" src="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path}" alt="${data.title}" width="45" height="67" srcset="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path} 1x, https://media.themoviedb.org/t/p/w90_and_h134_bestv2${data.poster_path} 2x">
#           # } else { #
#             <div class="glyphicons_v2 picture grey no_image_holder w45_and_h67"></div>
#           # } #
#         </div>
#
#         <div class="content">
#           <p class="name">${data.name}</p>
#           <p class="sub">
#             # if (data.media_type) { #
#                 <span class="media_type tv">#= public_media_type_map[data.media_type] # &bull; </span>
#               # } #
#             # if (data.original_name !== data.name) { #
#               <span class="comma"><span class="original_title">#= data.original_name #</span></span>
#             # } #
#             # if (data.first_air_date) { #
#               <span class="comma"><span class="release_date">#= data.first_air_date #</span></span>
#             # } #
#           </p>
#         </div>
#       </div>
#   </script>
#   <script id="slim_movie_result_template" type="text/x-kendo-tmpl">
#    <div class="ac_item poster list_item">
#         <div class="image_content poster">
#           # if (data.poster_path) { #
#             <img class="" src="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path}" alt="${data.title}" width="45" height="67" srcset="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path} 1x, https://media.themoviedb.org/t/p/w90_and_h134_bestv2${data.poster_path} 2x">
#           # } else { #
#             <div class="glyphicons_v2 picture grey no_image_holder w45_and_h67"></div>
#           # } #
#         </div>
#
#         <div class="content">
#           <p class="name">${data.title}</p>
#           <p class="sub">
#             # if (data.original_title !== data.title) { #
#               <span class="comma"><span class="original_title">#= data.original_title #</span></span>
#             # } #
#             # if (data.release_date) { #
#               <span class="comma"><span class="release_date">#= data.release_date #</span></span>
#             # } #
#           </p>
#         </div>
#
#         <p><span class="media_type movie">#= public_media_type_map[data.media_type] #</span></p>
#       </div>
#   </script>
#   <script id="multi_search_template" type="text/x-kendo-tmpl">
#    <div class="ac_results">
#         # if (data.media_type == 'movie') { #
#           #= kendo.render(kendo.template($("\\#movie_result_template").html()), [data]) #
#         # } else if (data.media_type == 'tv') { #
#           #= kendo.render(kendo.template($("\\#tv_show_result_template").html()), [data]) #
#         # } else if (data.media_type == 'person') { #
#           #= kendo.render(kendo.template($("\\#person_result_template").html()), [data]) #
#         # } #
#       </div>
#   </script>
#   <script id="search_v4_headerTemplate" type="text/x-kendo-template">
#    <div id="trending_search_header_template" class="slim_search_results_header">
#         <div class="wrapper">
#           <h2><span class="glyphicons_v2 trending"></span> Trending</h2>
#         </div>
#       </div>
#   </script>
#   <script id="search_no_data_template" type="text/x-kendo-template">
#    <div class="slim_search_results_header no_data">
#         <div class="wrapper">
#           <h2>No Results</h2>
#         </div>
#       </div>
#   </script>
#   <script id="slim_multi_search_template" type="text/x-kendo-tmpl">
#    # if (data.media_type == 'movie') { #
#         <div class="slim_search_results slim">
#           <div class="wrapper">
#             <div class="glyphicons_v2 film"></div>
#             <p>#= data.name # <span>in Movies</span></p>
#           </div>
#         </div>
#       # } else if (data.media_type == 'tv') { #
#         <div class="slim_search_results slim">
#           <div class="wrapper">
#             <div class="glyphicons_v2 tv"></div>
#             <p>#= data.name # <span>in TV Shows</span></p>
#           </div>
#         </div>
#       # } else if (data.media_type == 'person') { #
#         <div class="slim_search_results slim">
#           <div class="wrapper">
#             <div class="glyphicons_v2 user"></div>
#             <p>#= data.name # <span>in People</span></p>
#           </div>
#         </div>
#       # } else { #
#         <div class="slim_search_results slim">
#           <div class="wrapper">
#             <div class="glyphicons_v2 search"></div>
#             <p>#= data #</p>
#           </div>
#         </div>
#       # } #
#   </script>
#   <script id="delete-confirmation" type="text/x-kendo-template">
#    <section class="window_content">
#         <p class="delete-message">Are you sure?</p>
#
#         <button class="delete-cancel k-button">No</button>
#         <button class="delete-confirm k-button">Yes</button>
#       </section>
#   </script>
#   <div id="dialog_window">
#   </div>
#   <span class="hide" id="notification">
#   </span>
#   <script id="errorTemplate" type="text/x-kendo-template">
#    <div class="notification error">
#         <span>
#           <h2><span class="glyphicons_v2 circle-alert invert svg"></span> #= title #</h2>
#           # if (message instanceof Array) { #
#             <ul>
#               # for (var i = 0; i < message.length; i++) { #
#                 <li>#= message[i] #</li>
#               # } #
#             </ul>
#           # } else { #
#             <p>#= message #</p>
#           # } #
#         </span>
#       </div>
#   </script>
#   <script id="successTemplate" type="text/x-kendo-template">
#    <div class="notification success">
#         <span>
#           <h2><span class="glyphicons_v2 circle-check invert svg"></span> #= title #</h2>
#           <p>#= message #</p>
#         </span>
#       </div>
#   </script>
#   <script id="network_combo_template" type="text/x-kendo-tmpl">
#    <span class="k-state-default image">
#         # if (data.logo_path) { #
#           <img src="https://media.themoviedb.org/t/p/h15${data.logo_path}" alt="${data.name}" srcset="https://media.themoviedb.org/t/p/h15${data.logo_path} 1x, https://media.themoviedb.org/t/p/h30${data.logo_path} 2x" height="15">&nbsp;&nbsp;-&nbsp;
#         # } #
#         ${data.name}# if (data.origin_country) { # (${data.origin_country}) # } #
#       </span>
#   </script>
#   <script type="application/ld+json">
#    {
#         "@context": "http://schema.org",
#         "@type": "WebSite",
#         "name": "The Movie Database",
#         "alternateName": "TMDB",
#         "url": "https://www.themoviedb.org"
#       }
#   </script>
#   <script type="application/ld+json">
#    {
#          "@context": "http://schema.org",
#          "@type": "WebSite",
#          "url": "https://www.themoviedb.org/",
#          "potentialAction": {
#            "@type": "SearchAction",
#            "target": "https://www.themoviedb.org/search?query={search_term_string}",
#            "query-input": "required name=search_term_string"
#          }
#       }
#   </script>
#  </body>
# </html>

# %%
first_movie_content=movie_content.find("div", class_="card style_1")
print(first_movie_content)
# Out:
# <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/933131" title="Badland Hunters">
# <img alt="Badland Hunters" class="poster" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/24CL0ySodCF8bcm38xtBeHzHp7W.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/24CL0ySodCF8bcm38xtBeHzHp7W.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/24CL0ySodCF8bcm38xtBeHzHp7W.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="933131" data-media-type="movie" data-object-id="61f812b1fe6c180068897669">
# <a class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 61f812b1fe6c180068897669" data-bar-color="#d2d531" data-percent="69.28" data-track-color="#423d0f">
# <div class="percent">
# <span class="icon icon-r69"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/933131" title="Badland Hunters">Badland Hunters</a></h2>
# <p>Jan 26, 2024</p>
# </div>
# <div class="hover 933131"></div>
# </div>

# %%
first_movie_title=movie_content.find("div", class_="card style_1").h2.a.text
print(first_movie_title)
# Out:
# Badland Hunters

# %%
first_movie_rating=movie_content.find("div", class_="user_score_chart").get('data-percent')
print(first_movie_rating)
# Out:
# 69.28

# %%
first_movie_url=movie_content.find("div", class_="card style_1").h2.a.get('href')
print(first_movie_url[1:])
# Out:
# movie/933131

# %% [markdown]
# 4) Write some user defined functions.

# %%
def get_all_movie_title(mov_info):
    movie_title_list=[]
    movie_cards=mov_info.find_all("div", class_="card style_1")
    for movie in movie_cards:
        movie_title_list.append(movie.h2.a.text)
    return movie_title_list
print(get_all_movie_title(movie_content))
# Out:
# ['Badland Hunters', 'Sixty Minutes', 'Wonka', 'The Marvels', 'The Beekeeper', 'Lift', 'Migration', 'Wish', 'Aquaman and the Lost Kingdom', 'Orion and the Dark', 'The Hunger Games: The Ballad of Songbirds & Snakes', "The Tiger's Apprentice", 'The Painter', 'Role Play', 'Anyone But You', 'Napoleon', 'Trunk: Locked In', 'The Family Plan', 'Rebel Moon - Part One: A Child of Fire', 'One More Shot']

# %%
def get_all_movie_ratings(mov_info):
    movie_rating_list=[]
    movie_cards=mov_info.find_all("div", class_="user_score_chart")
    for movie in movie_cards:
        if movie['data-percent'] == '0':
            movie_rating_list.append('Not rated')
        else:
            movie_rating_list.append(movie['data-percent'])
    return movie_rating_list
print(get_all_movie_ratings(movie_content))
# Out:
# ['69.28', '71.0', '72.15', '63.129999999999995', '73.04', '65.84', '77.0', '66.36', '69.17', '68.19', '72.21000000000001', '70.66', '71.0', '60.099999999999994', '70.74', '65.22', '56.0', '73.5', '64.17', '67.9']

# %%
def get_all_html_content(mov_info):
    movie_cards=mov_info.find_all("div", class_="card style_1")
    each_movie_html_content_list=[]
    for movie in movie_cards:
        movie_link=movie.h2.a['href']
        each_movie_html=get_webpage_source('https://www.themoviedb.org'+movie_link)
        each_movie_html_content_list.append(each_movie_html)
    return each_movie_html_content_list
all_movie_page_content= get_all_html_content(movie_content)

# %%
def get_movie_genre(movie_page_content):
    genre=[]
    for movie in movie_page_content:
        genre_tags=movie.find("span", class_="genres")
        genre.append([anchor.text for anchor in genre_tags.find_all("a")])
    return genre

genres_each_movie_list=get_movie_genre(all_movie_page_content)
print(genres_each_movie_list)
# Out:
# [['Science Fiction', 'Action', 'Drama'], ['Action', 'Drama'], ['Comedy', 'Family', 'Fantasy'], ['Science Fiction', 'Adventure', 'Action'], ['Action', 'Thriller', 'Drama'], ['Action', 'Comedy', 'Crime'], ['Animation', 'Action', 'Adventure', 'Comedy', 'Family'], ['Animation', 'Family', 'Fantasy', 'Adventure'], ['Action', 'Adventure', 'Fantasy'], ['Animation', 'Family', 'Comedy', 'Fantasy'], ['Drama', 'Science Fiction', 'Action'], ['Animation', 'Action', 'Adventure', 'Family', 'Fantasy'], ['Action', 'Thriller'], ['Action', 'Comedy', 'Romance'], ['Comedy', 'Romance'], ['History', 'War', 'Action', 'Drama'], ['Thriller', 'Action', 'Drama'], ['Action', 'Comedy'], ['Science Fiction', 'Drama', 'Action'], ['Action', 'Thriller']]

# %%
def get_movie_cast(movie_page_content):
    cast=[]
    cast_tags=[]
    for movie in movie_page_content:
        cast_tags.append(movie.select('.card > p > a'))
    for cast_tag in cast_tags:
        cast.append([anchor.text for anchor in cast_tag])
    return cast
cast_each_movie_list=get_movie_cast(all_movie_page_content)
print(cast_each_movie_list)
# Out:
# [['Ma Dong-seok', 'Lee Hee-jun', 'Lee Jun-young', 'Roh Jeong-eui', 'Ahn Ji-hye', 'Park Ji-hoon', 'Jang Young-nam', 'Park Hyo-joon', 'Seong Byeong-suk'], ['Emilio Sakraya', 'Dennis Mojen', 'Marie Mouroum', 'Florian Schmidtke', 'Paul Wollin', 'Aristo Luis', 'Morik Heydo', 'Alain Blazevic', 'Harry Szovik'], ['Timothée Chalamet', 'Calah Lane', 'Keegan-Michael Key', 'Hugh Grant', 'Paterson Joseph', 'Olivia Colman', 'Tom Davis', 'Jim Carter', 'Rowan Atkinson'], ['Brie Larson', 'Teyonah Parris', 'Iman Vellani', 'Zawe Ashton', 'Samuel L. Jackson', 'Gary Lewis', 'Park Seo-jun', 'Zenobia Shroff', 'Mohan Kapur'], ['Jason Statham', 'Emmy Raver-Lampman', 'Bobby Naderi', 'Josh Hutcherson', 'Jeremy Irons', 'Taylor James', 'Phylicia Rashād', 'Jemma Redgrave', 'Minnie Driver'], ['Kevin Hart', 'Gugu Mbatha-Raw', 'Sam Worthington', "Vincent D'Onofrio", 'Úrsula Corberó', 'Billy Magnussen', 'Kim Yun-jee', 'Viveik Kalra', 'Jean Reno'], ['Kumail Nanjiani', 'Elizabeth Banks', 'Caspar Jennings', 'Tresi Gazal', 'Awkwafina', 'Carol Kane', 'Keegan-Michael Key', 'Danny DeVito', 'David Mitchell'], ['Ariana DeBose', 'Chris Pine', 'Alan Tudyk', 'Angelique Cabral', 'Victor Garber', 'Natasha Rothwell', 'Jennifer Kumiyama', 'Harvey Guillén', 'Niko Vargas'], ['Jason Momoa', 'Patrick Wilson', 'Yahya Abdul-Mateen II', 'Randall Park', 'Amber Heard', 'Nicole Kidman', 'Dolph Lundgren', 'Temuera Morrison', 'Indya Moore'], ['Jacob Tremblay', 'Paul Walter Hauser', 'Angela Bassett', 'Colin Hanks', 'Natasia Demetriou', 'Golda Rosheuvel', 'Nat Faxon', 'Aparna Nancherla', 'Ike Barinholtz'], ['Tom Blyth', 'Rachel Zegler', 'Peter Dinklage', 'Jason Schwartzman', 'Hunter Schafer', 'Josh Andrés Rivera', 'Viola Davis', 'Dexter Sol Ansell', 'Rosa Gotzler'], ['Brandon Soo Hoo', 'Henry Golding', 'Lucy Liu', 'Sandra Oh', 'Michelle Yeoh', 'Bowen Yang', 'Leah Lewis', 'Tan Kheng Hua', 'Sherry Cola'], ['Charlie Weber', 'Jon Voight', 'Madison Bailey', 'Max Montesi', 'Marie Avgeropoulos', 'Rryla McIntosh', "Luisa d'Oliveira", 'Leah Gibson', 'Jason Gray-Stanford'], ['Kaley Cuoco', 'David Oyelowo', 'Bill Nighy', 'Connie Nielsen', 'Rudi Dharmalingam', 'Lucia Aliu', 'Reagan Bryan-Gudgeon', 'Simon Delaney', 'Sonita Henry'], ['Sydney Sweeney', 'Glen Powell', 'Alexandra Shipp', 'Michelle Hurd', 'Bryan Brown', 'Darren Barnet', 'Hadley Robinson', 'Dermot Mulroney', 'Rachel Griffiths'], ['Joaquin Phoenix', 'Vanessa Kirby', 'Tahar Rahim', 'Rupert Everett', 'Mark Bonnar', 'Paul Rhys', 'Ben Miles', 'Riana Duce', 'Ludivine Sagnier'], ['Sina Martens', 'Artjom Gilz', 'Luise Helm', 'Poal Cairo', 'Charles Rettinghaus', 'Janina Sachau'], ['Mark Wahlberg', 'Michelle Monaghan', 'Maggie Q', 'Zoe Colletti', 'Van Crosby', 'Ciarán Hinds', 'Kellen Boyle', 'Saïd Taghmaoui', 'Felicia Pearson'], ['Sofia Boutella', 'Michiel Huisman', 'Ed Skrein', 'Djimon Hounsou', 'Bae Doona', 'Staz Nair', 'Charlie Hunnam', 'Ray Fisher', 'Cleopatra Coleman'], ['Scott Adkins', 'Michael Jai White', 'Alexis Knapp', 'Meena Rayann', 'Waleed Elgadi', 'Hannah Arterton', 'Tom Berenger', 'Jill Winternitz', 'Cassidy Little']]

# %% [markdown]
# 5)  Write an user defined function that returns a pandas data frame

# %%
import pandas as pd
def get_pandas_dataframe(home_page_content,individual_page_content):
    title=get_all_movie_title(home_page_content)
    rating=get_all_movie_ratings(home_page_content)
    genre=get_movie_genre(individual_page_content)
    cast=get_movie_cast(individual_page_content)
    movie_data = pd.DataFrame({
        "Movie Title": title,
        "Movie Rating": rating,
        "Movie Genre": genre,
        "Movie Cast": cast
    })
    return movie_data

movies_df=get_pandas_dataframe(movie_content,all_movie_page_content)
movies_df.head()
# Out:
#        Movie Title        Movie Rating                           Movie Genre  \
# 0  Badland Hunters               69.28      [Science Fiction, Action, Drama]
# 1    Sixty Minutes                71.0                       [Action, Drama]
# 2            Wonka               72.15             [Comedy, Family, Fantasy]
# 3      The Marvels  63.129999999999995  [Science Fiction, Adventure, Action]
# 4    The Beekeeper               73.04             [Action, Thriller, Drama]
#
#                                           Movie Cast
# 0  [Ma Dong-seok, Lee Hee-jun, Lee Jun-young, Roh...
# 1  [Emilio Sakraya, Dennis Mojen, Marie Mouroum, ...
# 2  [Timothée Chalamet, Calah Lane, Keegan-Michael...
# 3  [Brie Larson, Teyonah Parris, Iman Vellani, Za...
# 4  [Jason Statham, Emmy Raver-Lampman, Bobby Nade...

# %% [markdown]
# 6)  Scraping the data and combining the dataframes

# %%
import os

base_link="https://www.themoviedb.org/movie"
csv_folder = input("Please enter the directory name to store the generated CSVs: ")
# Out:
# Please enter the directory name to store the generated CSVs: Pooja_TMDB_CSVs_Folder

# %%
# Create folder if it doesn't exist
os.makedirs(csv_folder, exist_ok=True)

# %%
def get_multiple_pages_data(base_url,total_num_pages):
    dataframes_list=[]
    for page_no in range(1,total_num_pages+1):
        current_page_url=base_url+f'?page={page_no}'
        current_page_content=get_webpage_source(current_page_url)
        current_page_all_movies_content= get_all_html_content(current_page_content)
        current_data_frame=get_pandas_dataframe(current_page_content,current_page_all_movies_content)
        dataframes_list.append(current_data_frame)
    return dataframes_list
output_data_frames=  get_multiple_pages_data(base_link,5)

# %%
output_data_frames[0].head()
# Out:
#        Movie Title        Movie Rating                           Movie Genre  \
# 0  Badland Hunters               69.28      [Science Fiction, Action, Drama]
# 1    Sixty Minutes                71.0                       [Action, Drama]
# 2            Wonka               72.15             [Comedy, Family, Fantasy]
# 3      The Marvels  63.129999999999995  [Science Fiction, Adventure, Action]
# 4    The Beekeeper               73.04             [Action, Thriller, Drama]
#
#                                           Movie Cast
# 0  [Ma Dong-seok, Lee Hee-jun, Lee Jun-young, Roh...
# 1  [Emilio Sakraya, Dennis Mojen, Marie Mouroum, ...
# 2  [Timothée Chalamet, Calah Lane, Keegan-Michael...
# 3  [Brie Larson, Teyonah Parris, Iman Vellani, Za...
# 4  [Jason Statham, Emmy Raver-Lampman, Bobby Nade...

# %%
output_data_frames[1].head()
# Out:
#       Movie Title Movie Rating                                  Movie Genre  \
# 0    Silent Night        63.69  [Action, Adventure, Thriller, Crime, Drama]
# 1  The Bricklayer        62.27                           [Action, Thriller]
# 2       Freelance        65.62                             [Action, Comedy]
# 3     Due Justice        67.78                    [Crime, Thriller, Action]
# 4     Expend4bles        63.84                [Action, Adventure, Thriller]
#
#                                           Movie Cast
# 0  [Joel Kinnaman, Kid Cudi, Harold Torres, Catal...
# 1  [Aaron Eckhart, Nina Dobrev, Clifton Collins J...
# 2  [John Cena, Alison Brie, Juan Pablo Raba, Alic...
# 3  [Kellan Lutz, William Forsythe, Jeff Fahey, Ef...
# 4  [Jason Statham, Sylvester Stallone, 50 Cent, M...

# %%
output_data_frames[2].head()
# Out:
#                              Movie Title       Movie Rating  \
# 0                         The Underdoggs              60.69
# 1  Monsters 103 Mercies Dragon Damnation              80.98
# 2                             Night Swim              59.55
# 3                   Trolls Band Together  72.61999999999999
# 4                                Radical              84.93
#
#                                    Movie Genre  \
# 0                                     [Comedy]
# 1      [Animation, Action, Fantasy, Adventure]
# 2                                     [Horror]
# 3  [Animation, Family, Music, Fantasy, Comedy]
# 4                                      [Drama]
#
#                                           Movie Cast
# 0  [Snoop Dogg, Tika Sumpter, Elias Ferguson, Jon...
# 1  [Yoshimasa Hosoya, Kana Hanazawa, Hiroki Touch...
# 2  [Wyatt Russell, Kerry Condon, Amélie Hoeferle,...
# 3  [Anna Kendrick, Justin Timberlake, Camila Cabe...
# 4  [Eugenio Derbez, Daniel Haddad, Jennifer Trejo...

# %%
output_data_frames[3].head()
# Out:
#                            Movie Title       Movie Rating  \
# 0                         Gran Turismo              79.42
# 1                                  Leo              75.17
# 2                             My Fault  80.28999999999999
# 3  Spider-Man: Across the Spider-Verse               84.0
# 4                         Genghis Khan               53.5
#
#                                        Movie Genre  \
# 0                       [Adventure, Action, Drama]
# 1                      [Animation, Comedy, Family]
# 2                                 [Drama, Romance]
# 3  [Animation, Action, Adventure, Science Fiction]
# 4                     [Fantasy, Action, Adventure]
#
#                                           Movie Cast
# 0  [Archie Madekwe, David Harbour, Orlando Bloom,...
# 1  [Adam Sandler, Bill Burr, Cecily Strong, Jason...
# 2  [Nicole Wallace, Gabriel Guevara, Marta Hazas,...
# 3  [Shameik Moore, Hailee Steinfeld, Jason Schwar...
# 4  [William Chan Wai-Ting, Lin Yun, Hu Jun, Ni Da...

# %%
output_data_frames[4].head()
# Out:
#                       Movie Title Movie Rating  \
# 0                        The Duel         65.0
# 1  Guardians of the Galaxy Vol. 3        79.83
# 2                 Erik Stoneheart         40.0
# 3         Spider-Man: No Way Home        79.75
# 4                     Turning Red         74.0
#
#                             Movie Genre  \
# 0               [Action, Comedy, Crime]
# 1  [Science Fiction, Adventure, Action]
# 2          [Family, Adventure, Fantasy]
# 3  [Action, Adventure, Science Fiction]
# 4  [Animation, Family, Comedy, Fantasy]
#
#                                           Movie Cast
# 0  [Eugenia Suárez, Joaquín Furriel, Juan Ignacio...
# 1  [Chris Pratt, Zoe Saldaña, Dave Bautista, Kare...
# 2  [Herman Avandi, Florin Gussak, Juhan Ulfsak, L...
# 3  [Tom Holland, Zendaya, Benedict Cumberbatch, J...
# 4  [Rosalie Chiang, Sandra Oh, Ava Morse, Hyein P...

# %%
def generate_csv(df_list):
    #Storing each data frame in a separate CSV file
    for i, dataframe in enumerate(output_data_frames,start=1):
        # Define the file path within the new directory
        file_path = os.path.join(csv_folder, f'movie_page_{i}.csv')
        # Save the DataFrame to the CSV file
        dataframe.to_csv(file_path, index=False)
    return True
csv_flag=generate_csv(output_data_frames)
if csv_flag:
    print(f"Sucessfully generated {len(output_data_frames)} CSVs and stored it in directory named: {csv_folder}")
else:
    print(f"Something went wrong...")
# Out:
# Sucessfully generated 5 CSVs and stored it in directory named: Pooja_TMDB_CSVs_Folder

# %%
dataframe_list= get_multiple_pages_data(base_link,5)
consolidated_dataframe=pd.concat(dataframe_list, ignore_index=True)
consolidated_dataframe.head()
# Out:
#        Movie Title        Movie Rating                           Movie Genre  \
# 0  Badland Hunters               69.28      [Science Fiction, Action, Drama]
# 1    Sixty Minutes                71.0                       [Action, Drama]
# 2            Wonka               72.15             [Comedy, Family, Fantasy]
# 3      The Marvels  63.129999999999995  [Science Fiction, Adventure, Action]
# 4    The Beekeeper               73.04             [Action, Thriller, Drama]
#
#                                           Movie Cast
# 0  [Ma Dong-seok, Lee Hee-jun, Lee Jun-young, Roh...
# 1  [Emilio Sakraya, Dennis Mojen, Marie Mouroum, ...
# 2  [Timothée Chalamet, Calah Lane, Keegan-Michael...
# 3  [Brie Larson, Teyonah Parris, Iman Vellani, Za...
# 4  [Jason Statham, Emmy Raver-Lampman, Bobby Nade...

# %%
consolidated_dataframe.shape
# Out:
# (100, 4)

# %% [raw]
# 5 Dataframes created are combined and stored in a final dataframe named 'consolidated_dataframe' that has total of 100 rows and 4 columns.
